# %%
from __future__ import division
import psycopg2
import pandas as pd
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import datetime
import numpy as np
from difflib import SequenceMatcher
import re

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

import sys
sys.path.insert(0, '/Users/Naekid/Desktop/capstone-DSI-5/ebay-price-predictor/data-analysis/utilities/')
from plot_learning_curve import plot_learning_curve
from clean_text import clean_text

pd.set_option('display.max_colwidth',100)

# %% [markdown]
# ## Import Data

# %% [markdown]
# **Import cleaned auction data**

# %%
auctions = pd.read_pickle('../pickles/auctions.p')

# %% [markdown]
# **Clean Title Text**

# %%
auctions['title'] = auctions['title'].apply(clean_text)

# %% [markdown]
# ## Extract Brands,Models from postgres table

# %%
dbname='ebay'
user='nathan'
host='localhost'
table_name='b_h_digital_camera_inventory'

conn = psycopg2.connect("dbname={} user={} host={}".format(dbname, user, host))
cur = conn.cursor()


# Get Brands
SQL = '''SELECT "Brand" FROM b_h_digital_camera_inventory'''.format(table_name=table_name)
brands = pd.read_sql_query(sql=SQL, con=conn)
brands = brands['Brand'].unique().tolist()

# Get Models
SQL = '''SELECT "Title" FROM b_h_digital_camera_inventory'''.format(table_name=table_name)
titles = pd.read_sql_query(sql=SQL, con=conn)
titles = titles['Title'].unique().tolist()

# %% [markdown]
# **Clean brands and models text**

# %%
brands = [brand.lower() for brand in brands]
bh_titles = [clean_text(title) for title in titles]

# %%
brands
# Out:
# ['panasonic',
#  'sony',
#  'canon',
#  'fujifilm',
#  'nikon',
#  'ricoh',
#  'olympus',
#  'leica',
#  'pentax',
#  'lytro',
#  'kodak',
#  'polaroid',
#  'hasselblad',
#  'dxo',
#  'sigma',
#  'vivitar',
#  'yi technology',
#  'panono',
#  'minox',
#  'sealife',
#  'hamiltonbuhl',
#  'horseman',
#  'mamiya',
#  'mamiya leaf']

# %% [markdown]
# ## Find Brand
# ---

# %%
def find_brand(title):
    for brand in brands:
        if brand in title:
            return brand

# %%
auctions['brand'] = auctions['title'].apply(find_brand)

# %% [markdown]
# ## Find Model

# %% [markdown]
# ### use NLP + Cosine Similarity to find listing Model
# ---

# %%
auctions['model'] = ''

# %% [markdown]
# ** Delete Lens from Title **

# %%
bad_words = ['digital','camera','mm','lens','bag','sd','card','new',\
             'used','broken','cracked', 'kit','zoom','power','brand',\
            'package','bag','shutter','body','black','box','original',\
             'battery','charger','mp','accessories','dslr', 'slr', 'basic','kit','mirrorless']



def filter_title(title):
    for brand in brands:
        title = title.replace(brand, '')    
    for w in bad_words:
        title = title.replace(w, '')
    title = re.sub(r"\d+\-\d+","",title)
    title = re.sub(r"\d+\.\d+","",title)
    
    title = re.sub(r"\s\d+\s"," ",title) # deleting numbers
    title = re.sub(r"\s\d+\s"," ",title) # deleting numbers
    title = re.sub(r"\s\-\s"," ",title)  # deleting individual dashes 
    return title

# %% [markdown]
# Test

# %%
test_title = auctions['title'].iloc[592]
test_title = auctions['title'].iloc[22]
test_title = auctions['title'].iloc[12]
print test_title


filter_title(test_title)
# Out:
# olympus e-3 10.1 mp digital slr camera - black body - 23 597 activations
# u' e-3        activations'

# %% [markdown]
# **Filter listing titles to prepare for model extraction**

# %%
auctions['filtered_titles'] = auctions['title'].apply(filter_title)

# %% [markdown]
# **Filter bh photo titles to prepare for model extraction**

# %%
models = [filter_title(title).strip() for title in bh_titles]

# %% [markdown]
# **Train Vectorizer on available Models**

# %%
vectorizer = TfidfVectorizer(ngram_range=(1,1),
                            min_df = 1,
                            max_features=5000)

# vectorizer = CountVectorizer(ngram_range=(1,1),
#                             min_df = 1,
#                             max_features=5000)

models_matrix = vectorizer.fit_transform(models)

models_df = pd.DataFrame(models_matrix.todense(), columns=vectorizer.vocabulary_.keys())
print models_df.shape
# Out:
# (717, 364)

# %% [markdown]
# ** Transform Titles using Models Vectorizer **

# %%
# vectorizer = TfidfVectorizer(ngram_range=(1,2),
#                             min_df = 10,
#                             max_features=5000)

titles_matrix = vectorizer.transform(auctions['filtered_titles'].tolist())
print titles_matrix.shape
# Out:
# (29961, 364)

# %% [markdown]
# **Create vectorized titles df**

# %%
titles_df = pd.DataFrame(titles_matrix.todense(), columns=vectorizer.vocabulary_.keys())

titles_df = pd.concat(objs=[titles_df,auctions['title'],auctions['filtered_titles'],auctions['brand']], axis=1)

titles_df['similarity_score'] = None
titles_df['model_name'] = ''

titles_df.reset_index(inplace=True) # for using the index column to compare results with the auctions df

# %% [markdown]
# **Use Cosine Similarity to match title with model**

# %%
test_df = titles_df.copy()
print test_df.shape
for test_index in range(1000):
    title_vector = test_df.iloc[test_index, 1:-5].values
    
    similarity_matrix = cosine_similarity(X=title_vector.reshape(1,-1), Y=models_matrix)[0]
    
    match_index = np.argmax(similarity_matrix)
    
    test_df['similarity_score'].iloc[test_index] = np.max(similarity_matrix)
    test_df['model_name'].iloc[test_index] = models[match_index]
# Out:
# (29961, 370)

# %%
models
# Out:
# [u'lumix dc-gh5 mirrorless micro four thirds',
#  u'alpha a7r ii mirrorless',
#  u'alpha a6500 mirrorless',
#  u'alpha a5000 mirrorless',
#  u'cyber-shot dsc-w800',
#  u'eos 5d mark iv',
#  u'x100f',
#  u'x-t2 mirrorless',
#  u'lumix dmc-g85 mirrorless micro four thirds',
#  u'd3300     es',
#  u'shot g7 x mark ii',
#  u'd500',
#  u'cyber-shot dsc-rx100 v',
#  u'alpha a7s ii mirrorless',
#  u'lumix dmc-zs50   silver',
#  u'x100f   silver',
#  u'alpha a5000 mirrorless     white',
#  u'd750    storage',
#  u'cyber-shot dsc-rx100 v',
#  u'alpha a7s ii mirrorless   rode videomic pro',
#  u'eos 7d mark ii    storage',
#  u'eos 5d mark iv    storage',
#  u'coolpix p900',
#  u'theta spherical vr',
#  u'alpha a99 ii',
#  u'om-d e-m1 mark ii mirrorless micro four thirds',
#  u'x-t20 mirrorless     silver',
#  u'eos rebel t6     es',
#  u'om-d e-m10 mark ii mirrorless micro four thirds    ii r  silver',
#  u'dsc-w830   silver',
#  u'alpha a6000 mirrorless',
#  u'eos 5d mark iii    storage',
#  u'lumix dc-fz80',
#  u'shot g9 x',
#  u'd3400     es',
#  u'eos rebel t6i',
#  u'd810    storage',
#  u'eos 6d    f 4l  storage',
#  u'alpha a7 ii mirrorless',
#  u'alpha a5000 mirrorless     silver',
#  u'eos rebel t6i     es',
#  u'eos rebel t7i',
#  u'd3200',
#  u'eos 77d',
#  u'shot elph   silver',
#  u'd5500      refurbished',
#  u'eos 80d      es',
#  u'x-t2 mirrorless     grip',
#  u'eos 80d     video creator',
#  u'alpha a6300 mirrorless',
#  u'd-lux typ',
#  u'lumix dmc-zs100',
#  u'shot sx720 hs',
#  u'd500',
#  u'lumix dmc-lx10',
#  u'gr ii',
#  u'eos 6d    storage',
#  u'x-t20 mirrorless',
#  u'eos rebel t6i     video creator',
#  u'shot g9 x mark ii',
#  u'd500    refurbished',
#  u'lumix dmc-g7 mirrorless micro four thirds',
#  u'alpha a6000 mirrorless',
#  u'alpha a6300 mirrorless',
#  u'd3400',
#  u'cyber-shot dsc-rx10 iii',
#  u'eos rebel t6',
#  u'eos-1d x mark ii',
#  u'shot sx530 hs',
#  u'om-d e-m10 mark ii mirrorless micro four thirds    ii r',
#  u'cyber-shot dsc-rx10 iii   free accessory',
#  u'alpha a6500 mirrorless     es',
#  u'lumix dmc-lx100',
#  u'alpha a6000 mirrorless     es',
#  u'eos rebel t5i     video creator',
#  u'coolpix s7000',
#  u'shot elph   red',
#  u'shot g7 x mark ii   video creator',
#  u'd5600',
#  u'lumix dmc-gh4 mirrorless micro four thirds',
#  u'lumix dmc-ts30',
#  u'cyber-shot dsc-hx80',
#  u'eos rebel t5     es bundle',
#  u'alpha a6300 mirrorless     es',
#  u'dsc-w830',
#  u'finepix xp90   yellow',
#  u'x-t1 mirrorless',
#  u'q typ',
#  u'x-t1 mirrorless',
#  u'lumix dmc-ts30   blue',
#  u'shot elph',
#  u'x-pro2 mirrorless',
#  u'd3400',
#  u'd7200    refurbished',
#  u'lumix dmc-fz1000',
#  u'lumix dmc-zs100   silver',
#  u'k-1',
#  u'eos m5 mirrorless',
#  u'cyber-shot dsc-hx90v',
#  u'shot sx620 hs',
#  u'cyber-shot dsc-w800   silver',
#  u'k-70',
#  u'alpha a6500 mirrorless',
#  u'eos rebel sl1',
#  u'eos rebel t6',
#  u'coolpix p900   refurbished',
#  u'lumix dc-gh5 mirrorless micro four thirds   filaking',
#  u'lumix dmc-fz300',
#  u'cyber-shot dsc-hx400v',
#  u'eos m6 mirrorless',
#  u'shot sx60 hs',
#  u'd7100     dual  wi-fi',
#  u'shot g9 x mark ii   silver',
#  u'om-d e-m10 mark ii mirrorless micro four thirds',
#  u'lumix dmc-g7 mirrorless micro four thirds     silver',
#  u'eos rebel sl1',
#  u'gfx 50s medium format mirrorless',
#  u'shot g9 x   silver',
#  u'd5    storage  dual xqd slots',
#  u'eos 5d mark iv    f 4l ii',
#  u'eos 5d mark iv   f ii  storage',
#  u'eos 80d      es',
#  u'eos rebel t7i',
#  u'coolpix b700',
#  u'coolpix b500',
#  u'om-d e-m10 mark ii mirrorless micro four thirds     es',
#  u'cyber-shot dsc-rx100',
#  u'x-t2 mirrorless',
#  u'd7100',
#  u'alpha a5100 mirrorless',
#  u'alpha a7 ii mirrorless   fe  f 3..6 oss',
#  u'alpha a7 mirrorless',
#  u'shot sx610 hs',
#  u'om-d e-m10 mark ii mirrorless micro four thirds    silver',
#  u'pen-f mirrorless micro four thirds    silver',
#  u'eos 5d mark iii     storage',
#  u'eos m6 mirrorless     silver',
#  u'm10  rangefinder',
#  u'illum light field',
#  u'coolpix a900',
#  u'coolpix l340',
#  u'lumix dmc-gx85 mirrorless micro four thirds',
#  u'alpha a7 mirrorless   fe  f 3..6 oss',
#  u'eos 70d     es',
#  u'd810     storage',
#  u'om-d e-m5 mark ii mirrorless micro four thirds',
#  u'eos rebel t7i     es',
#  u'shot g5 x',
#  u'coolpix a900   silver',
#  u'lumix dmc-fz2500',
#  u'alpha a6000 mirrorless     graphite',
#  u'cyber-shot dsc-rx100 iv',
#  u'eos m5 mirrorless',
#  u'eos-1d x mark ii   premium  64gb  reader',
#  u'shot elph hs',
#  u'pixpro fz53   red',
#  u'd610    external hard drive',
#  u'lumix dmc-g85 mirrorless micro four thirds',
#  u'k-70',
#  u'alpha a6500 mirrorless',
#  u'eos m3 mirrorless     ef-m  adapter',
#  u'coolpix a10',
#  u'd5600',
#  u'lumix dmc-gx85 mirrorless micro four thirds',
#  u'alpha a5100 mirrorless     white',
#  u'alpha a6000 mirrorless     white',
#  u'alpha a7r ii mirrorless    f',
#  u'x-t2 mirrorless    graphite silver edition',
#  u'x100t   silver',
#  u'shot sx620 hs   red',
#  u'cyber-shot dsc-rx100 iii',
#  u'eos m5 mirrorless',
#  u'coolpix s3700   pink',
#  u'd3400     es red',
#  u'd5600',
#  u'cyber-shot dsc-hx400    accessory',
#  u'cyber-shot dsc-wx220',
#  u'eos 7d mark ii    w-e1 wi-fi adapter',
#  u'eos rebel t6i     es',
#  u'shot elph hs   purple',
#  u'shot elph hs   silver',
#  u'x-a3 mirrorless     brown',
#  u'x-t20 mirrorless',
#  u'q typ   titanium gray',
#  u'coolpix a300',
#  u'd5300   dual',
#  u'd5600     es',
#  u'lumix dmc-ts30   red',
#  u'lumix dmc-zs50   silver refurbished',
#  u'eos rebel t6i     video creator',
#  u'shot g3 x   evf-dc1 electronic viewfinder',
#  u'd5    dual xqd slots',
#  u'eos 5ds    storage',
#  u'x-pro2 mirrorless   f  graphite',
#  u'lumix dmc-lx100   silver',
#  u'coolpix p530    refurbished',
#  u'eos 70d     video creator',
#  u'eos m6 mirrorless',
#  u'shot sx610 hs   red',
#  u'm10  rangefinder  silver',
#  u'd5300      refurbished',
#  u'lumix dmc-lx10   free accessory',
#  u'ie x29   red',
#  u'eos 5d mark iii     storage',
#  u'eos 7d mark ii     storage',
#  u'eos rebel sl1     es bundle',
#  u'eos rebel t6i',
#  u'shot d30 waterproof   blue',
#  u'x-a3 mirrorless     silver',
#  u'coolpix b500   red',
#  u'd7200',
#  u'd750    adobe creative cloud 12-month subscription',
#  u'lumix dmc-gx85 mirrorless micro four thirds     silver',
#  u'eos 5d mark iii    f 4l  deluxe',
#  u'x1d-50c medium format mirrorless',
#  u'eos 80d',
#  u'eos 77d',
#  u'x-t20 mirrorless    silver',
#  u'shot sx620 hs   silver',
#  u'pixpro fz43',
#  u'k-3 ii',
#  u'ie090   blue',
#  u'eos rebel t7i',
#  u'shot elph   blue',
#  u'one   wi-fi',
#  u'finepix xp90   lime',
#  u'coolpix s33   white refurbished',
#  u'coolpix w100   white',
#  u'd5    dual xqd slots refurbished',
#  u'om-d e-m1 mark ii mirrorless micro four thirds   f',
#  u'pen-f mirrorless micro four thirds',
#  u'lumix dmc-zs60',
#  u'k-s2',
#  u'kp',
#  u'alpha a6000 mirrorless     silver',
#  u'eos 70d     video creator',
#  u'eos 77d    usm',
#  u'eos 77d     es',
#  u'eos 7d mark ii    f 3..6 stm',
#  u'eos m3 mirrorless',
#  u'eos rebel t6i',
#  u'eos m6 mirrorless',
#  u'eos rebel t5     es bundle deluxe',
#  u'shot sx610 hs   white',
#  u'x1d-50c edition medium format mirrorless',
#  u'coolpix l840    refurbished',
#  u'coolpix s3700   red',
#  u'd3400       red',
#  u'd750    deluxe',
#  u'om-d e-m5 mark ii mirrorless micro four thirds    f',
#  u'lumix dmc-g7 mirrorless micro four thirds',
#  u'k-s2     es',
#  u'snap instant   purple',
#  u'cyber-shot dsc-wx350',
#  u'eos 5d mark iii',
#  u'eos 7d mark ii    f 3..6 usm  w-e1 wi-fi adapter',
#  u'eos 80d     video',
#  u'finepix xp90   blue',
#  u'x-pro2 mirrorless   f',
#  u'x70',
#  u'v-lux typ',
#  u'coolpix s3700   silver',
#  u'd750',
#  u'd500',
#  u'quattro h mirrorless',
#  u'alpha a6000 mirrorless    graphite',
#  u'coolpix w100   blue',
#  u'alpha a6300 mirrorless',
#  u'cyber-shot dsc-rx1r ii',
#  u'ilce-qx1 mirrorless -style',
#  u'eos 7d mark ii      photo',
#  u'eos m10 mirrorless',
#  u'eos m3 mirrorless     white',
#  u'eos rebel t5i     es',
#  u'eos rebel t5i    f 3..6 stm',
#  u'eos rebel t5i     video creator',
#  u'finepix xp90   orange',
#  u'x-a3 mirrorless     pink',
#  u'x70   silver',
#  u'pixpro az421   red',
#  u'monochrom typ  rangefinder',
#  u'd4s',
#  u'd5    storage  dual cf slots',
#  u'd750     deluxe',
#  u'd810    adobe creative cloud 12-month subscription',
#  u'om-d e-m5 mark ii mirrorless micro four thirds    silver',
#  u'k-s2     es  orange',
#  u'theta sc spherical   blue',
#  u'ie x29',
#  u'theta sc spherical   white',
#  u'lumix dc-gx850 micro four thirds mirrorless',
#  u'alpha a7r mirrorless',
#  u'cyber-shot dsc-h300',
#  u'f126   pink',
#  u'eos 5d mark iii    deluxe',
#  u'eos 5d mark iv    f 4l',
#  u'eos 70d     es',
#  u'eos 70d     video',
#  u'eos 80d     video',
#  u'eos rebel sl1     es',
#  u'eos rebel sl1',
#  u'eos-1d x',
#  u'shot elph   red',
#  u'shot sx420   red',
#  u'x-t10   es',
#  u'x-t10 mirrorless',
#  u'x-t2 mirrorless      grip',
#  u'd3300',
#  u'd3400     red',
#  u'd5    dual cf slots refurbished',
#  u'd810    deluxe',
#  u'd810 dlsr',
#  u'd500    deluxe',
#  u'd7200    deluxe',
#  u'd7200',
#  u'd810     deluxe',
#  u'om-d e-m10 mark ii mirrorless micro four thirds',
#  u'lumix dmc-gx8 mirrorless micro four thirds',
#  u'k-1',
#  u'k-s2     white',
#  u'snap touch instant   blue',
#  u'alpha a5100 mirrorless',
#  u'alpha a68',
#  u'alpha a77 ii',
#  u'alpha a7s mirrorless',
#  u'cyber-shot dsc-wx500',
#  u'vivicam x054   blue',
#  u'eos 5d mark iii   adobe creative cloud photography plan',
#  u'eos 6d    deluxe',
#  u'eos 6d   adobe creative cloud photography plan',
#  u'eos 7d mark ii',
#  u'eos 80d',
#  u'eos 80d',
#  u'eos m3 mirrorless     es',
#  u'x-t10 mirrorless',
#  u'shot g3 x',
#  u'eos rebel t6s',
#  u'x-e2s mirrorless',
#  u'shot sx420',
#  u'x-t20 mirrorless     silver',
#  u'pixpro fz43   red',
#  u'1 j5 mirrorless     white',
#  u'd5    dual cf slots',
#  u'd500',
#  u'd500     deluxe',
#  u'k-1',
#  u'snap instant   white',
#  u'alpha a68',
#  u'cyber-shot dsc-h400',
#  u'cyber-shot dsc-rx100 ii',
#  u'vivicam x054',
#  u'shot g5 x   pixma pro-100 printer',
#  u'eos 6d    f 4l',
#  u'eos 7d mark ii     video',
#  u'eos 7d mark ii   adobe creative cloud photography plan',
#  u'eos 7d mark ii   pixma pro-100 printer',
#  u'eos 80d   video',
#  u'eos 80d     storage',
#  u'eos 80d     deluxe',
#  u'eos rebel t5i    stm',
#  u'eos rebel t5i     es',
#  u'eos rebel t6     es',
#  u'eos m10 mirrorless     white',
#  u'eos rebel t6s     es',
#  u'shot g1 x mark ii',
#  u'shot sx730 hs',
#  u'pixpro fz53',
#  u'pixpro fz53   blue',
#  u'd-lux typ   explorer',
#  u'sl typ mirrorless',
#  u'1 j5 mirrorless     es silver',
#  u'1 j5 mirrorless',
#  u'1 j5 mirrorless     silver',
#  u'd610     es',
#  u'd750    video',
#  u'd810     video',
#  u'air a01 mirrorless micro four thirds -style',
#  u'pen e-pl8 mirrorless micro four thirds',
#  u'lumix dmc-gx8 mirrorless micro four thirds    silver',
#  u'645z medium format',
#  u'k-1',
#  u'alpha a7r ii mirrorless    f',
#  u'alpha a7s ii mirrorless    f',
#  u'alpha a6000 mirrorless    silver',
#  u'k-s2',
#  u'm1 mirrorless micro four thirds     ice silver',
#  u'eos 5d mark iv    f  storage',
#  u'eos 6d',
#  u'eos 70d    f 3..6 stm',
#  u'eos m6 mirrorless     silver',
#  u'eos rebel sl1     ef f  stm',
#  u'eos rebel t5i    stm  video',
#  u'eos rebel t7i     es',
#  u'eos-1d c',
#  u'shot sx530 hs   refurbished',
#  u'shot sx730 hs   silver',
#  u'x-a10 mirrorless',
#  u'x-e2s mirrorless',
#  u'x-t20 mirrorless',
#  u'typ  rangefinder  suarit-m f   sf flash bundle',
#  u'm-d typ  rangefinder',
#  u'tl mirrorless   silver',
#  u'tl mirrorless   titanium',
#  u'x-u typ',
#  u'1 aw1 mirrorless   .5',
#  u'1 j5 mirrorless     white',
#  u'd3400     deluxe',
#  u'1 v3 mirrorless',
#  u'1 j5 mirrorless     silver',
#  u'd500     video',
#  u'd7200    video',
#  u'd7200   macro  dental',
#  u'd810a',
#  u'df   f   silver',
#  u'air a01 mirrorless micro four thirds -style    ez  white',
#  u'om-d e-m10 mark ii mirrorless micro four thirds      silver',
#  u'lumix dmc-zs60   silver',
#  u'360  colete',
#  u'ie090   red',
#  u'is048   blue',
#  u'is048   teal',
#  u'snap instant',
#  u'snap instant   blue',
#  u'snap touch instant   purple',
#  u'snap touch instant   white',
#  u'theta sc spherical   beige',
#  u'wg-30w   flame orange',
#  u'quattro mirrorless   f  art',
#  u'alpha a7s ii mirrorless    f',
#  u'alpha a77 ii    f',
#  u'alpha a6000 mirrorless     es  white',
#  u'cyber-shot dsc-rx10 ii',
#  u'cyber-shot dsc-wx350   white',
#  u'cyber-shot dsc-wx500   white',
#  u'aquashot underwater   solid turquoise blue',
#  u'f126   blue',
#  u'frozen',
#  u'shot g9 x   pixma pro-100 printer',
#  u'eos 5d mark iii   pixma pro-100 printer',
#  u'eos 5d mark iii   video production   f 4l usm af',
#  u'eos 5d mark iii    f 4l',
#  u'eos 5d mark iii',
#  u'eos 5d mark iii     adobe creative cloud photography plan',
#  u'eos 5d mark iii    f 4l  video production',
#  u'eos 5ds',
#  u'eos 5ds r',
#  u'eos 6d    video',
#  u'eos 6d    f 4l',
#  u'eos 6d    f 4l  adobe creative cloud photography plan',
#  u'eos 6d     pixma pro-100 printer',
#  u'eos 6d   ef  f 4l usm  video',
#  u'eos 70d    video',
#  u'eos 80d     deluxe',
#  u'eos 7d mark ii    video',
#  u'eos 80d   deluxe',
#  u'eos 77d    usm  es',
#  u'eos 70d    f 3..6 stm',
#  u'eos m3 mirrorless',
#  u'eos m6 mirrorless    silver',
#  u'eos rebel t5i     deluxe',
#  u'eos-1d x   pixma pro-100 printer',
#  u'finepix xp120   sky blue',
#  u'finepix xp120   yellow',
#  u'x-e2s mirrorless     silver',
#  u'x-t1 mirrorless',
#  u'x-t10 mirrorless',
#  u'h6d-100c medium format',
#  u'pixpro fz201 friendly',
#  u'm-p typ  rangefinder',
#  u'tl mirrorless',
#  u'dcc    silver',
#  u'1 aw1 mirrorless   .5 es',
#  u'1 aw1 mirrorless   .5  silver',
#  u'1 aw1 mirrorless   .5  white',
#  u'1 j5 mirrorless     es white',
#  u'd3400     deluxe  red',
#  u'd7100     deluxe',
#  u'd610',
#  u'd610',
#  u'd3400   es',
#  u'd7500',
#  u'df',
#  u'df    silver',
#  u'pen e-pl8 mirrorless micro four thirds',
#  u'pen e-pl8 mirrorless micro four thirds     brown',
#  u'pen e-pl8 mirrorless micro four thirds     white',
#  u'lumix dc-gx850 micro four thirds mirrorless    silver',
#  u'k-70    silver',
#  u'k-70     silver',
#  u'k-s2',
#  u'k-s2     orange',
#  u'k-s2     stone gray',
#  u'k-s2     white lime',
#  u'kp    silver',
#  u'is048   red',
#  u'snap instant   pink',
#  u'snap instant   red',
#  u'snap touch instant',
#  u'snap touch instant   pink',
#  u'g800se',
#  u'alpha a7 ii mirrorless',
#  u'alpha a6000 mirrorless     es  silver',
#  u'dp0 quattro   lvf-01 lcd viewfinder',
#  u'micro hd underwater   16gb',
#  u'quattro mirrorless',
#  u'alpha a77 ii     f   f 3..6 es',
#  u'cyber-shot dsc-rx1 full frame coact',
#  u'cyber-shot dsc-rx10',
#  u'vivicam s126   pink',
#  u'vivicam x054   red',
#  u'vivicam x054   white',
#  u'eos 5d mark iii',
#  u'eos 5d mark iii    video production',
#  u'eos 5d mark iii     pixma pro-100 printer',
#  u'eos 5d mark iii',
#  u'eos 5d mark iii     pixma pro-100 printer',
#  u'eos 5d mark iv    microphone',
#  u'eos 6d',
#  u'eos 6d   deluxe   f 4l usm af',
#  u'eos 6d    f 3..6 stm',
#  u'eos 6d   pixma pro-100 printer',
#  u'eos 70d',
#  u'eos 70d     deluxe',
#  u'eos 70d    deluxe',
#  u'eos 70d    f 3..6 stm',
#  u'eos 70d',
#  u'eos 70d    pixma pro-100 inkjet printer',
#  u'eos 70d    stm  printer',
#  u'eos 70d    f 3..6 stm',
#  u'eos 70d     pixma pro-100 printer',
#  u'eos 70d     deluxe',
#  u'eos 70d     video',
#  u'eos 7d mark ii    f 3..6 stm  adobe creative cloud photography plan',
#  u'eos 7d mark ii   microphone',
#  u'eos 80d',
#  u'eos 80d     es video creator',
#  u'eos 80d',
#  u'eos 80d',
#  u'eos m10 mirrorless     es',
#  u'eos rebel sl1     stm  inkjet printer',
#  u'eos rebel sl1     deluxe',
#  u'eos rebel t5',
#  u'eos rebel t5i',
#  u'eos rebel t5i     stm  pixma pro-100 inkjet printer',
#  u'eos rebel t5i',
#  u'eos rebel t5i     deluxe',
#  u'eos rebel t6     deluxe',
#  u'eos rebel t5i    stm  video',
#  u'eos rebel t5i',
#  u'eos rebel t5i     pixma pro-100 printer',
#  u'eos rebel t6i     pixma pro-100 printer',
#  u'eos rebel t6i     pixma pro-100 printer',
#  u'eos rebel t6s    pixma pro-100 printer',
#  u'eos rebel t6s',
#  u'eos rebel t6s     pixma pro-100 printer',
#  u'shot sx540 hs',
#  u'shot sx710 hs',
#  u'finepix xp120   blue',
#  u'finepix xp120   lime',
#  u'x-e2s mirrorless    silver',
#  u'x-t1 ir mirrorless  forensic bundle',
#  u'x-t1 ir mirrorless',
#  u'x-t1 mirrorless  forensic bundle',
#  u'x-t1 mirrorless    graphite silver edition',
#  u'x100t   wide-angle conversion   silver',
#  u'explorer  six -dc2 s',
#  u'a5d-50c aerial',
#  u'a5d-50c near infrared aerial',
#  u'h5d-200c multi-shot medium format',
#  u'a5d-80 near infrared aerial',
#  u'a5d-80 aerial',
#  u'h5d-50c multi-shot medium format',
#  u'h5x medium format     grip hv 90x-ii viewfinder',
#  u'h5x medium format     grip hvd 90x viewfinder',
#  u'h5x medium format     grip',
#  u'h6d-50c medium format',
#  u'h6x medium format',
#  u'h6x medium format  hv 90x-ii viewfinder',
#  u'h6x medium format  hvd 90x viewfinder',
#  u'sw612d    v  backs',
#  u'sw612d     backs',
#  u'sw612d  set  v  backs',
#  u'sw612d  set   backs',
#  u'pixpro fz201 friendly    red',
#  u'typ  rangefinder',
#  u'typ  rangefinder  suarit-m f  es sf flash bundle',
#  u'typ  rangefinder  suarit-m f   sf flash bundle',
#  u'rangefinder',
#  u'rangefinder   silver',
#  u'm-p typ  rangefinder  silver chrome',
#  u'typ medium format',
#  u'suicron edition medium format',
#  u'leaf credo  back  645df medium format  f  ls',
#  u'645df medium format   f  ls',
#  u'645df medium format',
#  u'645df medium format    f  ls',
#  u'credo system  645df  f  ls',
#  u'credo  back  645df medium format  f  ls af',
#  u'credo  back  645df medium format  f  ls af  gold  warranty',
#  u'dcc',
#  u'coolpix aw130 waterproof',
#  u'coolpix aw130 waterproof   blue',
#  u'coolpix aw130 waterproof   orange',
#  u'coolpix l32',
#  u'coolpix p530',
#  u'd3200     deluxe',
#  u'd3200  dental',
#  u'd3300      gray',
#  u'd3300',
#  u'd3300      refurbished',
#  u'd3300     gray',
#  u'd3300     red',
#  u'd3300     red refurbished',
#  u'd3x    refurbished',
#  u'd500    video',
#  u'd500   sports wildlife',
#  u'd5300',
#  u'd5200',
#  u'd5300    gray',
#  u'd5300    red',
#  u'd5300',
#  u'd5300     es',
#  u'd5300',
#  u'd5300     gray',
#  u'd5300     red',
#  u'd5300   af-p',
#  u'd5500',
#  u'd5500    red',
#  u'd5500',
#  u'd5500     red',
#  u'd5500',
#  u'd5500     red',
#  u'd5500   af-p',
#  u'd610',
#  u'd610    deluxe',
#  u'd610',
#  u'd610     deluxe',
#  u'd610',
#  u'd7100    video production',
#  u'd7100    refurbished',
#  u'd7100',
#  u'd7100',
#  u'd7100    deluxe',
#  u'd7100   video production   f 3..6',
#  u'd7100',
#  u'd7100',
#  u'd7100     es',
#  u'd7200',
#  u'd7200   tamron macro  dental',
#  u'd750',
#  u'd750    refurbished',
#  u'd750',
#  u'd810',
#  u'd810    refurbished',
#  u'd810    video',
#  u'd810    microphone',
#  u'd810',
#  u'df   f',
#  u'lumix dmc-gh4 4k mirrorless micro four thirds     f  asph.',
#  u'pen e-pl8 mirrorless micro four thirds    white',
#  u'air a01 mirrorless micro four thirds -style    white',
#  u'stylus tough tg-4   red',
#  u'stylus tough tg-4',
#  u'pro set',
#  u'645z medium format  corehensive starter',
#  u'k-s2    white',
#  u'k-s2      orange',
#  u'k-s2     white',
#  u'k-s2     es white',
#  u'k-s2      racing stripe',
#  u'k-s2      orange',
#  u'k-s2      pink',
#  u'k-s2     desert beige',
#  u'k-s2     white racing stripe',
#  u'kp',
#  u'kp      silver',
#  u'kp',
#  u'kp      silver',
#  u'kp',
#  u'kp      silver',
#  u'kp',
#  u'kp     silver',
#  u'snap touch instant   red',
#  u'itt28   red',
#  u'itt28',
#  u'is126   red',
#  u'is126',
#  u'gr ii   premium',
#  u'theta sc spherical   pink',
#  u'wg-30w   carbon gray',
#  u'dp0 quattro',
#  u'dp1 quattro',
#  u'dp1 quattro   lvf-01 viewfinder',
#  u'dp2 quattro',
#  u'dp2 quattro   lvf-01 viewfinder',
#  u'dp3 quattro',
#  u'dp3 quattro   lvf-01 lcd viewfinder',
#  u'1 merrill',
#  u'alpha a77 ii',
#  u'alpha a77 ii    deluxe',
#  u'alpha a77 ii',
#  u'alpha a77 ii    f    grip',
#  u'alpha a77 ii',
#  u'cyber-shot dsc-rx1r',
#  u'aquashot underwater   patterned turquoise blue',
#  u'vivicam s126',
#  u'vivicam s126   blue',
#  u'vivicam xx14',
#  u'vivicam s126   purple',
#  u'vivicam s131   white',
#  u'vivicam t016',
#  u'vivicam xx14   red',
#  u'm1 mirrorless micro four thirds     es storm',
#  u'd5500 af-p dx',
#  u'd3300      open',
#  u'd5300      open',
#  u'd5500      open']

# %%
for i,model in enumerate(models):
    if "eos" in model:
        print bh_titles[i]
        print model
# Out:
# eos 5d mark iv dslr camera body
# eos 5d mark iv
# eos 7d mark ii dslr camera body storage kit
# eos 7d mark ii    storage
# eos 5d mark iv dslr camera body storage kit
# eos 5d mark iv    storage
# eos rebel t6 dslr camera 18-55mm 75-300mm lenses kit
# eos rebel t6     es
# eos 5d mark iii dslr camera body storage kit
# eos 5d mark iii    storage
# eos rebel t6i dslr camera 18-55mm lens
# eos rebel t6i
# eos 6d dslr camera 24-105mm f 4l lens storage kit
# eos 6d    f 4l  storage
# eos rebel t6i dslr camera 18-55mm 55-250mm lenses kit
# eos rebel t6i     es
# eos rebel t7i dslr camera body
# eos rebel t7i
# eos 77d dslr camera body
# eos 77d
# eos 80d dslr camera body 18-55mm 55-250mm lenses kit
# eos 80d      es
# eos 80d dslr camera 18-135mm lens video creator kit
# eos 80d     video creator
# eos 6d dslr camera body storage kit
# eos 6d    storage
# eos rebel t6i dslr camera 18-55mm lens video creator kit
# eos rebel t6i     video creator
# eos rebel t6 dslr camera 18-55mm lens
# eos rebel t6
# eos-1d x mark ii dslr camera body
# eos-1d x mark ii
# eos rebel t5i dslr camera 18-55mm lens video creator kit
# eos rebel t5i     video creator
# eos rebel t5 dslr camera 18-55mm 75-300mm lenses bundle
# eos rebel t5     es bundle
# eos m5 mirrorless digital camera 18-150mm lens
# eos m5 mirrorless
# eos rebel sl1 dslr camera 18-55mm lens black
# eos rebel sl1
# eos rebel t6 dslr camera 18-55mm lens basic kit
# eos rebel t6
# eos m6 mirrorless digital camera 15-45mm lens black
# eos m6 mirrorless
# eos rebel sl1 dslr camera body
# eos rebel sl1
# eos 5d mark iv dslr camera 24-105mm f 4l ii lens
# eos 5d mark iv    f 4l ii
# eos 5d mark iv dslr 24-105mm f 4 ii lens storage kit
# eos 5d mark iv   f ii  storage
# eos 80d dslr camera body 18-135mm 55-250mm lenses kit
# eos 80d      es
# eos rebel t7i dslr camera 18-55mm lens
# eos rebel t7i
# eos 5d mark iii dslr camera 24-105mm lens storage kit
# eos 5d mark iii     storage
# eos m6 mirrorless digital camera 15-45mm lens silver
# eos m6 mirrorless     silver
# eos 70d dslr camera 18-55mm 55-250mm lenses kit
# eos 70d     es
# eos rebel t7i dslr camera 18-55mm 55-250mm lenses kit
# eos rebel t7i     es
# eos m5 mirrorless digital camera body
# eos m5 mirrorless
# eos-1d x mark ii dslr camera premium kit 64gb card reader
# eos-1d x mark ii   premium  64gb  reader
# eos m3 mirrorless digital camera 18-55mm lens ef-m lens adapter kit black
# eos m3 mirrorless     ef-m  adapter
# eos m5 mirrorless digital camera 15-45mm lens
# eos m5 mirrorless
# eos 7d mark ii dslr camera body w-e1 wi-fi adapter
# eos 7d mark ii    w-e1 wi-fi adapter
# eos rebel t6i dslr camera 18-135mm 55-250mm lenses kit
# eos rebel t6i     es
# eos rebel t6i dslr camera 18-55mm lens video creator kit 55-250mm lens
# eos rebel t6i     video creator
# eos 5ds dslr camera body storage kit
# eos 5ds    storage
# eos 70d dslr camera 18-135mm lens video creator kit
# eos 70d     video creator
# eos m6 mirrorless digital camera 18-150mm lens black
# eos m6 mirrorless
# eos 5d mark iii dslr camera 24-70mm lens storage kit
# eos 5d mark iii     storage
# eos 7d mark ii dslr camera 18-135mm lens storage kit
# eos 7d mark ii     storage
# eos rebel sl1 dslr camera 18-55mm 75-300mm lenses bundle
# eos rebel sl1     es bundle
# eos rebel t6i dslr camera 18-135mm lens
# eos rebel t6i
# eos 5d mark iii dslr camera 24-105mm f 4l lens deluxe kit
# eos 5d mark iii    f 4l  deluxe
# eos 80d dslr camera 18-135mm lens basic kit
# eos 80d
# eos 77d dslr camera 18-55mm lens
# eos 77d
# eos rebel t7i dslr camera 18-135mm lens
# eos rebel t7i
# eos 70d dslr camera 18-135mm lens video creator kit 55-250mm lens
# eos 70d     video creator
# eos 77d dslr camera 18-135mm usm lens
# eos 77d    usm
# eos 77d dslr camera 18-55mm 55-250mm lenses kit
# eos 77d     es
# eos 7d mark ii dslr camera 18-135mm f 3.5-5.6 stm lens
# eos 7d mark ii    f 3..6 stm
# eos m3 mirrorless digital camera 18-55mm lens black
# eos m3 mirrorless
# eos rebel t6i dslr camera body
# eos rebel t6i
# eos m6 mirrorless digital camera body black
# eos m6 mirrorless
# eos rebel t5 dslr camera 18-55mm 75-300mm lenses bundle deluxe kit
# eos rebel t5     es bundle deluxe
# eos 5d mark iii dslr camera body basic kit
# eos 5d mark iii
# eos 7d mark ii dslr camera 18-135mm f 3.5-5.6 usm lens w-e1 wi-fi adapter
# eos 7d mark ii    f 3..6 usm  w-e1 wi-fi adapter
# eos 80d dslr camera 18-135mm lens video kit
# eos 80d     video
# eos 7d mark ii dslr camera 18-135mm lens basic photo kit
# eos 7d mark ii      photo
# eos m10 mirrorless digital camera 15-45mm lens black
# eos m10 mirrorless
# eos m3 mirrorless digital camera 18-55mm lens white
# eos m3 mirrorless     white
# eos rebel t5i dslr camera 18-55mm 55-250mm lenses kit
# eos rebel t5i     es
# eos rebel t5i dslr camera 18-55mm f 3.5-5.6 stm lens basic kit
# eos rebel t5i    f 3..6 stm
# eos rebel t5i dslr camera 18-55mm lens video creator kit 55-250mm lens
# eos rebel t5i     video creator
# eos 5d mark iii dslr camera body deluxe kit
# eos 5d mark iii    deluxe
# eos 5d mark iv dslr camera 24-70mm f 4l lens
# eos 5d mark iv    f 4l
# eos 70d dslr camera 18-135mm 55-250mm lenses kit
# eos 70d     es
# eos 70d dslr camera 18-135mm lens video kit
# eos 70d     video
# eos 80d dslr camera 18-55mm lens video kit
# eos 80d     video
# eos rebel sl1 dslr camera 18-55mm 55-250mm lenses kit black
# eos rebel sl1     es
# eos rebel sl1 dslr camera 18-55mm lens basic kit black
# eos rebel sl1
# eos-1d x dslr camera body
# eos-1d x
# eos 5d mark iii dslr camera adobe creative cloud photography plan kit
# eos 5d mark iii   adobe creative cloud photography plan
# eos 6d dslr camera body deluxe kit
# eos 6d    deluxe
# eos 6d dslr camera adobe creative cloud photography plan kit
# eos 6d   adobe creative cloud photography plan
# eos 7d mark ii dslr camera body
# eos 7d mark ii
# eos 80d dslr camera basic kit
# eos 80d
# eos 80d dslr camera 18-55mm lens basic kit
# eos 80d
# eos m3 mirrorless digital camera 18-55mm 55-200mm lenses black
# eos m3 mirrorless     es
# eos rebel t6s dslr camera body
# eos rebel t6s
# eos 6d dslr camera 24-105mm f 4l lens basic kit
# eos 6d    f 4l
# eos 7d mark ii dslr camera 18-135mm lens video kit
# eos 7d mark ii     video
# eos 7d mark ii dslr camera adobe creative cloud photography plan kit
# eos 7d mark ii   adobe creative cloud photography plan
# eos 7d mark ii dslr camera pixma pro-100 printer kit
# eos 7d mark ii   pixma pro-100 printer
# eos 80d dslr camera video kit
# eos 80d   video
# eos 80d dslr camera 18-135mm lens storage kit
# eos 80d     storage
# eos 80d dslr camera 18-135mm lens deluxe kit
# eos 80d     deluxe
# eos rebel t5i dslr camera 18-135mm stm lens basic kit
# eos rebel t5i    stm
# eos rebel t5i dslr camera 18-135mm 55-250mm lenses kit
# eos rebel t5i     es
# eos rebel t6 dslr camera 18-55mm 55-250mm lenses kit
# eos rebel t6     es
# eos m10 mirrorless digital camera 15-45mm lens white
# eos m10 mirrorless     white
# eos rebel t6s dslr camera 18-135mm 55-250mm lenses kit
# eos rebel t6s     es
# eos 5d mark iv dslr camera 24-70mm f 4 lens storage kit
# eos 5d mark iv    f  storage
# eos 6d dslr camera body basic kit
# eos 6d
# eos 70d dslr camera 18-135mm f 3.5-5.6 stm lens basic kit
# eos 70d    f 3..6 stm
# eos m6 mirrorless digital camera 18-150mm lens silver
# eos m6 mirrorless     silver
# eos rebel sl1 dslr camera body kit ef 40mm f 2.8 stm lens
# eos rebel sl1     ef f  stm
# eos rebel t5i dslr camera 18-135mm stm lens video kit
# eos rebel t5i    stm  video
# eos rebel t7i dslr camera 18-135mm 55-250mm lenses kit
# eos rebel t7i     es
# eos-1d c camera body
# eos-1d c
# eos 5d mark iii dslr camera pixma pro-100 printer kit
# eos 5d mark iii   pixma pro-100 printer
# eos 5d mark iii dslr camera video production kit 24-105mm f 4l usm af lens
# eos 5d mark iii   video production   f 4l usm af
# eos 5d mark iii dslr camera 24-105mm f 4l lens basic kit
# eos 5d mark iii    f 4l
# eos 5d mark iii dslr camera 24-105mm lens
# eos 5d mark iii
# eos 5d mark iii dslr camera 24-105mm lens adobe creative cloud photography plan kit
# eos 5d mark iii     adobe creative cloud photography plan
# eos 5d mark iii dslr camera 24-70mm f 4l lens video production kit
# eos 5d mark iii    f 4l  video production
# eos 5ds dslr camera body
# eos 5ds
# eos 5ds r dslr camera body
# eos 5ds r
# eos 6d dslr camera body video kit
# eos 6d    video
# eos 6d dslr camera 24-105mm f 4l lens
# eos 6d    f 4l
# eos 6d dslr camera 24-105mm f 4l lens adobe creative cloud photography plan kit
# eos 6d    f 4l  adobe creative cloud photography plan
# eos 6d dslr camera 24-105mm lens pixma pro-100 printer kit
# eos 6d     pixma pro-100 printer
# eos 6d dslr camera ef 24-105mm f 4l usm lens video kit
# eos 6d   ef  f 4l usm  video
# eos 70d dslr camera body video kit
# eos 70d    video
# eos 80d dslr camera 18-55mm lens deluxe kit
# eos 80d     deluxe
# eos 7d mark ii dslr camera body video kit
# eos 7d mark ii    video
# eos 80d dslr camera deluxe kit
# eos 80d   deluxe
# eos 77d dslr camera 18-135mm usm 55-250mm lenses
# eos 77d    usm  es
# eos 70d dslr camera 18-55mm f 3.5-5.6 stm lens basic kit
# eos 70d    f 3..6 stm
# eos m3 mirrorless digital camera body black
# eos m3 mirrorless
# eos m6 mirrorless digital camera body silver
# eos m6 mirrorless    silver
# eos rebel t5i dslr camera 18-55mm lens deluxe kit
# eos rebel t5i     deluxe
# eos-1d x dslr camera pixma pro-100 printer kit
# eos-1d x   pixma pro-100 printer
# eos 5d mark iii dslr camera body
# eos 5d mark iii
# eos 5d mark iii dslr camera body video production kit
# eos 5d mark iii    video production
# eos 5d mark iii dslr camera 24-105mm lens pixma pro-100 printer kit
# eos 5d mark iii     pixma pro-100 printer
# eos 5d mark iii dslr camera 24-70mm lens
# eos 5d mark iii
# eos 5d mark iii dslr camera 24-70mm lens pixma pro-100 printer kit
# eos 5d mark iii     pixma pro-100 printer
# eos 5d mark iv dslr camera body microphone kit
# eos 5d mark iv    microphone
# eos 6d dslr camera body
# eos 6d
# eos 6d dslr camera deluxe kit 24-105mm f 4l usm af lens
# eos 6d   deluxe   f 4l usm af
# eos 6d dslr camera 24-105mm f 3.5-5.6 stm lens
# eos 6d    f 3..6 stm
# eos 6d dslr camera pixma pro-100 printer kit
# eos 6d   pixma pro-100 printer
# eos 70d dslr camera body
# eos 70d
# eos 70d dslr camera 18-135mm lens deluxe kit
# eos 70d     deluxe
# eos 70d dslr camera body deluxe kit
# eos 70d    deluxe
# eos 70d dslr camera 18-135mm f 3.5-5.6 stm lens
# eos 70d    f 3..6 stm
# eos 70d dslr camera basic kit
# eos 70d
# eos 70d dslr camera kit pixma pro-100 inkjet printer
# eos 70d    pixma pro-100 inkjet printer
# eos 70d dslr camera 18-135mm stm lens printer kit
# eos 70d    stm  printer
# eos 70d dslr camera 18-55mm f 3.5-5.6 stm lens
# eos 70d    f 3..6 stm
# eos 70d dslr camera 18-55mm lens pixma pro-100 printer kit
# eos 70d     pixma pro-100 printer
# eos 70d dslr camera 18-55mm lens deluxe kit
# eos 70d     deluxe
# eos 70d dslr camera 18-55mm lens video kit
# eos 70d     video
# eos 7d mark ii dslr camera 18-135mm f 3.5-5.6 stm lens adobe creative cloud photography plan kit
# eos 7d mark ii    f 3..6 stm  adobe creative cloud photography plan
# eos 7d mark ii dslr camera microphone kit
# eos 7d mark ii   microphone
# eos 80d dslr camera body
# eos 80d
# eos 80d dslr camera 18-135mm 55-250mm lenses video creator kit
# eos 80d     es video creator
# eos 80d dslr camera 18-135mm lens
# eos 80d
# eos 80d dslr camera 18-55mm lens
# eos 80d
# eos m10 mirrorless digital camera 15-45mm 55-200mm lenses black
# eos m10 mirrorless     es
# eos rebel sl1 dslr camera kit 18-55mm stm lens inkjet printer
# eos rebel sl1     stm  inkjet printer
# eos rebel sl1 dslr camera 18-55mm lens deluxe kit black
# eos rebel sl1     deluxe
# eos rebel t5 dslr camera 18-55mm lens
# eos rebel t5
# eos rebel t5i dslr camera body
# eos rebel t5i
# eos rebel t5i dslr camera kit 18-135mm stm lens pixma pro-100 inkjet printer
# eos rebel t5i     stm  pixma pro-100 inkjet printer
# eos rebel t5i dslr camera 18-135mm lens
# eos rebel t5i
# eos rebel t5i dslr camera 18-135mm lens deluxe kit
# eos rebel t5i     deluxe
# eos rebel t6 dslr camera 18-55mm lens deluxe kit
# eos rebel t6     deluxe
# eos rebel t5i dslr camera 18-55mm stm lens video kit
# eos rebel t5i    stm  video
# eos rebel t5i dslr camera 18-55mm lens
# eos rebel t5i
# eos rebel t5i dslr camera 18-55mm lens pixma pro-100 printer kit
# eos rebel t5i     pixma pro-100 printer
# eos rebel t6i dslr camera 18-135mm lens pixma pro-100 printer kit
# eos rebel t6i     pixma pro-100 printer
# eos rebel t6i dslr camera 18-55mm lens pixma pro-100 printer kit
# eos rebel t6i     pixma pro-100 printer
# eos rebel t6s dslr camera body pixma pro-100 printer kit
# eos rebel t6s    pixma pro-100 printer
# eos rebel t6s dslr camera 18-135mm lens
# eos rebel t6s
# eos rebel t6s dslr camera 18-135mm lens pixma pro-100 printer kit
# eos rebel t6s     pixma pro-100 printer

# %%
similarity_score_threshold = 0.7
test_df[test_df['similarity_score']>similarity_score_threshold].ix[:, ['title','filtered_titles','brand','similarity_score','model_name']]
# Out:
#                                                                             title  \
# 0       canon eos rebel sl1 eos 100d 18.0 mp digital slr camera - black kit w stm
# 1         sony cyber-shot dsc-rx100 20.2mp digital camera - black brand new cheap
# 2      new nib canon eos rebel t6 digital slr camera premium kit 18-55mm 75-300mm
# 3            new canon eos rebel t6 dslr bundle 18-55mm 75-300mm lens bag sd card
# 7        panasonic lumix dmc-g7 mirrorless micro four thirds digital camera body
# 8                                 sony cyber-shot rx100 ii digital camera - black
# 10         sony cyber-shot dsc-hx300 20.4mp digital camera - black. original box.
# 11     as-is canon ds126491 eos rebel t5 digital slr camera kit w battery charger
# 13                                        sony cyber-shot dsc-h300 digital camera
# 16                        sony cyber-shot dsc-tx20 16.2 mp digital camera - green
# 20     ricoh theta 360 virtual reality vr digital camera - white - like brand new
# 21        polaroid snap touch instant print digital camera lcd display brand new
# 25                         canon powershot sx280 hs 12.1mp digital camera - black
# 35                nikon coolpix l340 20.2 mp digital mint camera - black warranty
# 38                                canon powershot sx610 hs - wi-fi enabled white
# 46                          canon powershot sx610 hs 20.2 mp digital camera - red
# 51                            canon powershot g7 x 20.2 mp digital camera - black
# 57                              sony cyber-shot dsc-hx100v 16.2 mp digital camera
# 61                          canon powershot sx610 hs 20.2 mp digital camera - red
# 64                              nikon coolpix p530 16.1 mp digital camera - black
# 67                                 canon powershot sx40 hs 12.1 mp digital camera
# 69                          canon powershot sx610 hs 20.2 mp digital camera - red
# 73                              nikon coolpix l340 20.2 mp digital camera - black
# 76                             canon powershot sx610 hs digital 20mp black camera
# 80                    nikon coolpix b700 digital camera 20.2 megapixels like new
# 81                             nikon d3200 24.2 mp 18-55mm lens grey spots issue.
# 83                        canon digital camera rebel eos ds6041 ef-s 18-55mm lens
# 84                         canon powershot sx50 hs 12.1 mp digital camera - black
# 85                                      nikon coolpix p530 digital camera - black
# 98         olympus stylus tg-860 white tough waterproof digital camera 3-inch lcd
# ..                                                                            ...
# 911            sony cyber-shot dsc-hx100v 16.2 mp digital camera 30x optical zoom
# 915  canon eos digital rebel xsi 12.2 mp digital slr camera kit lens case bundle.
# 920                           nikon coolpix l340 20.2 mp digital camera - black -
# 921         olympus om-d e-m10 mirrorless digital camera 14-42mm 2rk lens silver
# 927               canon eos 20d 8.2 mp digital slr camera w ef-s usm 17-85mm lens
# 930                   olympus stylus tough tg-860 16.0 mp digital camera - orange
# 936                        sony cyber-shot dsc-tx30 18.2mp digital camera - black
# 937     ricoh gxr camera s10 24-72 mm f2.5-4.4 vc lens wide angle conversion lens
# 938                                     canon powershot sx610 hs 20.2 mega pixels
# 944                nikon coolpix l340 20mp 28x optical zoom digital camera black
# 950                nikon coolpix l340 20mp 28x optical zoom digital camera black
# 954                nikon coolpix l340 20mp 28x optical zoom digital camera black
# 956                                                           polaroid snap touch
# 958                                    nikon d3300 24.2 mp cmos digital slr as-is
# 959        nikon d40 6.1mp digital slr camera - black kit w af-s dx 18-55mm lens
# 960       nikon d50 6.1 mp digital slr camera - black 2 nikon dx af-s lens extras
# 963        nikon d40 6.1mp digital slr camera - black kit w af-s dx 18-55mm lens
# 972                               nikon coolpix l840 16.0 mp digital camera - red
# 974       canon powershot elph 300 hs ixus 220 hs 12.1 mp digital camera - silver
# 975            olympus tough tg-2 ihs 12.0 mp case 8 gb card charging cable read
# 978            canon powershot elph 160 digital camera 20mp 8x 2.7 tft-lcd silver
# 981       nikon d40 6.1mp digital slr camera - black w af-s dx 18-55mm lens nice
# 982  nikon d3200 24.2 mp digital slr camera black body accessories original owner
# 986                                nikon coolpix s7000 16 mp digital camera used
# 989                              nikon coolpix l840 16.0mp digital camera - black
# 992   canon - powershot sx530 hs 16.0-megapixel digital camera - black sunpak 585
# 993                             nikon coolpix l340 20.2 mp digital camera - black
# 994     canon powershot sx400 16.0 mp digital camera - red kit w 4.3-129 mm lens
# 995                nikon coolpix l340 20mp 28x optical zoom digital camera black
# 997                nikon coolpix l340 20mp 28x optical zoom digital camera black
#
#                                         filtered_titles      brand  \
# 0                   eos rebel sl1 eos 100d        w stm      canon
# 1                      cyber-shot dsc-rx100       cheap       sony
# 2                       nib  eos rebel t6    premium         canon
# 3                            eos rebel t6  bundle            canon
# 7         lumix dmc-g7 mirrorless micro four thirds      panasonic
# 8                                cyber-shot rx100 ii          sony
# 10                         cyber-shot dsc-hx300    .  .       sony
# 11                 as-is  ds126491 eos rebel t5     w        canon
# 13                                cyber-shot dsc-h300         sony
# 16                        cyber-shot dsc-tx20     green       sony
# 20              theta virtual reality vr   white like        ricoh
# 21            snap touch instant print   lcd display      polaroid
# 25                                    shot sx280 hs          canon
# 35                      coolpix l340    mint   warranty      nikon
# 38                   shot sx610 hs wi-fi enabled white       canon
# 46                                shot sx610 hs     red      canon
# 51                                       shot g7 x           canon
# 57                            cyber-shot dsc-hx100v           sony
# 61                                shot sx610 hs     red      canon
# 64                                    coolpix p530           nikon
# 67                                     shot sx40 hs          canon
# 69                                shot sx610 hs     red      canon
# 73                                    coolpix l340           nikon
# 76                                     shot sx610 hs         canon
# 80                    coolpix b700    megapixels like        nikon
# 81                          d3200     grey spots issue.      nikon
# 83                              rebel eos ds6041 ef-s        canon
# 84                                    shot sx50 hs           canon
# 85                                      coolpix p530         nikon
# 98    stylus tg-860 white tough waterproof   3-inch lcd    olympus
# ..                                                  ...        ...
# 911              cyber-shot dsc-hx100v     30x optical        sony
# 915                  eos  rebel xsi        case bundle.      canon
# 920                                 coolpix l340      -      nikon
# 921               om-d e-m10 mirrorless    2rk  silver     olympus
# 927                           eos 20d      w ef-s usm        canon
# 930                      stylus tough tg-860     orange    olympus
# 936                             cyber-shot dsc-tx30           sony
# 937         gxr  s10   f2..4 vc  wide angle conversion       ricoh
# 938                          shot sx610 hs  mega pixels      canon
# 944                       coolpix l340 28x optical           nikon
# 950                       coolpix l340 28x optical           nikon
# 954                       coolpix l340 28x optical           nikon
# 956                                          snap touch   polaroid
# 958                                d3300   cmos   as-is      nikon
# 959                              d40       w af-s dx         nikon
# 960                          d50        dx af-s  extras      nikon
# 963                              d40       w af-s dx         nikon
# 972                                coolpix l840     red      nikon
# 974                     shot elph hs ixus hs     silver      canon
# 975      tough tg-2 ihs   case gb  charging cable read     olympus
# 978                      shot elph   8x  tft-lcd silver      canon
# 981                          d40      w af-s dx   nice       nikon
# 982                                d3200          owner      nikon
# 986                                  coolpix s7000           nikon
# 989                                    coolpix l840          nikon
# 992              shot sx530 hs -megapixel    sunpak 585      canon
# 993                                   coolpix l340           nikon
# 994                         shot sx400     red  w 4.         canon
# 995                       coolpix l340 28x optical           nikon
# 997                       coolpix l340 28x optical           nikon
#
#     similarity_score  \
# 0           0.826132
# 1                  1
# 2           0.746143
# 3           0.803468
# 7                  1
# 8           0.897523
# 10          0.774455
# 11                 1
# 13                 1
# 16          0.774455
# 20          0.763815
# 21          0.813209
# 25          0.732139
# 35           0.76385
# 38           0.74516
# 46                 1
# 51          0.805844
# 57          0.774455
# 61                 1
# 64                 1
# 67          0.732139
# 69                 1
# 73                 1
# 76                 1
# 80                 1
# 81                 1
# 83          0.724778
# 84          0.732139
# 85                 1
# 98          0.755394
# ..               ...
# 911         0.774455
# 915         0.727614
# 920                1
# 921         0.706405
# 927         0.734543
# 930         0.898014
# 936         0.774455
# 937         0.851828
# 938                1
# 944                1
# 950                1
# 954                1
# 956         0.832747
# 958                1
# 959         0.862069
# 960         0.862069
# 963         0.862069
# 972          0.77842
# 974         0.943198
# 975         0.816497
# 978         0.744536
# 981         0.862069
# 982                1
# 986                1
# 989         0.869309
# 992                1
# 993                1
# 994         0.700464
# 995                1
# 997                1
#
#                                                     model_name
# 0                                                eos rebel sl1
# 1                                       cyber-shot dsc-rx100 v
# 2                                                 eos rebel t6
# 3                                                 eos rebel t6
# 7                    lumix dmc-g7 mirrorless micro four thirds
# 8                                      cyber-shot dsc-rx100 ii
# 10                                      cyber-shot dsc-rx100 v
# 11                                                eos rebel t5
# 13                                         cyber-shot dsc-h300
# 16                                      cyber-shot dsc-rx100 v
# 20                                          theta spherical vr
# 21                                          snap touch instant
# 25                                                shot elph hs
# 35                                                coolpix l340
# 38                                       shot sx610 hs   white
# 46                                         shot sx610 hs   red
# 51                                           shot g7 x mark ii
# 57                                      cyber-shot dsc-rx100 v
# 61                                         shot sx610 hs   red
# 64                                                coolpix p530
# 67                                                shot elph hs
# 69                                         shot sx610 hs   red
# 73                                                coolpix l340
# 76                                               shot sx610 hs
# 80                                                coolpix b700
# 81                                                       d3200
# 83                                 eos rebel sl1     ef f  stm
# 84                                                shot elph hs
# 85                                                coolpix p530
# 98                                           stylus tough tg-4
# ..                                                         ...
# 911                                     cyber-shot dsc-rx100 v
# 915                                eos rebel sl1     es bundle
# 920                                               coolpix l340
# 921  om-d e-m10 mark ii mirrorless micro four thirds    silver
# 927                               eos 6d   ef  f 4l usm  video
# 930                                          stylus tough tg-4
# 936                                     cyber-shot dsc-rx100 v
# 937                     x100t   wide-angle conversion   silver
# 938                                              shot sx610 hs
# 944                                               coolpix l340
# 950                                               coolpix l340
# 954                                               coolpix l340
# 956                                         snap touch instant
# 958                                                      d3300
# 959                                              d5500 af-p dx
# 960                                              d5500 af-p dx
# 963                                              d5500 af-p dx
# 972                                coolpix l840    refurbished
# 974                                      shot elph hs   silver
# 975                                          stylus tough tg-4
# 978                                         shot elph   silver
# 981                                              d5500 af-p dx
# 982                                                      d3200
# 986                                              coolpix s7000
# 989                                coolpix l840    refurbished
# 992                                              shot sx530 hs
# 993                                               coolpix l340
# 994                                            shot elph   red
# 995                                               coolpix l340
# 997                                               coolpix l340
#
# [264 rows x 5 columns]

# %%
for model in test_df['filtered_titles'].tolist():
    if "dsc-hx300" in model:
        print model
# Out:
#  cyber-shot dsc-hx300    .  .
#  dsc-hx300
#  cyber-shot dsc-hx300
#  dsc-hx300
#  cyber-shot dsc-hx300      w  case
#  cyber-shot dsc-hx300
#  cyber-shot dsc-hx300
#  cyber-shot dsc-hx300     1080hd
#  cyber-shot dsc-hx300
#  cyber-shot dsc-hx300
#  dsc-hx300
#  cyber-shot dsc-hx300     works perfectly
#  cyber-shot dsc-hx300
#  cyber-shot dsc-hx300
#  cyber-shot dsc-hx300  50x optical
#  dsc-hx300
#  cyber-shot dsc-hx300
#  cyber-shot dsc-hx300
#  cyber-shot dsc-hx300
#  dsc-hx300
#  cyber-shot dsc-hx300    bonus 32gb 64gb  s
#  cyber-shot dsc-hx300
#  cyber-shot dsc-hx300      extra
#  cyber-shot dsc-hx300
#  cyber-shot dsc-hx300
#  cyber-shot dsc-hx300
#  as-is  cyber-shot dsc-hx300
#  dsc-hx300
#  cyber-shot dsc-hx300  50x optical
#  cyber-shot dsc-hx300
#  cyber-shot dsc-hx300

# %%
print auctions.ix[test_index,'title']
print titles_df.ix[test_index, ['title','filtered_titles']]

title_vector = titles_df.iloc[test_index, 1:-5].values

similarity_matrix = cosine_similarity(X=title_vector.reshape(1,-1), Y=models_matrix)[0]

match_index = np.argmax(similarity_matrix)

print np.max(similarity_matrix)

models[match_index]
# Out:
# sony dsc-hx300 digital camera
# title              sony dsc-hx300 digital camera
# filtered_titles                       dc-hx300
# Name: 19, dtype: object
# 0.707106781187
# 'dsc-hx300'

# %%
for row_num in range(titles_df.shape[0]):
    if row_num+1 % 100 == 0:
        print 'Extracting model name for item #{} out of {}'.format(row_num, titles_df.shape[0])

    title_vector = titles_df.iloc[row_num, 1:-5].values
    
    similarity_matrix = cosine_similarity(X=title_vector.reshape(1,-1), Y=models_matrix)[0]
    
    match_index = np.argmax(similarity_matrix)
    
    titles_df['similarity_score'] = np.max(similarity_matrix)
    
    titles_df['model_name'].iloc[row_num] = models[match_index]
# Out:
# Extracting model name for item #0 out of 29961
# /Users/Naekid/anaconda3/envs/dsi/lib/python2.7/site-packages/pandas/core/indexing.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# Extracting model name for item #100 out of 29961
# Extracting model name for item #200 out of 29961
# Extracting model name for item #300 out of 29961
# Extracting model name for item #400 out of 29961
# Extracting model name for item #500 out of 29961
# Extracting model name for item #600 out of 29961
# Extracting model name for item #700 out of 29961
# Extracting model name for item #800 out of 29961
# Extracting model name for item #900 out of 29961
# Extracting model name for item #1000 out of 29961
# Extracting model name for item #1100 out of 29961
# Extracting model name for item #1200 out of 29961
# Extracting model name for item #1300 out of 29961
# Extracting model name for item #1400 out of 29961
# Extracting model name for item #1500 out of 29961
# Extracting model name for item #1600 out of 29961
# Extracting model name for item #1700 out of 29961
# Extracting model name for item #1800 out of 29961
# Extracting model name for item #1900 out of 29961
# Extracting model name for item #2000 out of 29961
# Extracting model name for item #2100 out of 29961
# Extracting model name for item #2200 out of 29961
# Extracting model name for item #2300 out of 29961
# Extracting model name for item #2400 out of 29961
# Extracting model name for item #2500 out of 29961
# Extracting model name for item #2600 out of 29961
# Extracting model name for item #2700 out of 29961
# Extracting model name for item #2800 out of 29961
# Extracting model name for item #2900 out of 29961
# Extracting model name for item #3000 out of 29961
# Extracting model name for item #3100 out of 29961
# Extracting model name for item #3200 out of 29961
# Extracting model name for item #3300 out of 29961
# Extracting model name for item #3400 out of 29961
# Extracting model name for item #3500 out of 29961
# Extracting model name for item #3600 out of 29961
# Extracting model name for item #3700 out of 29961
# Extracting model name for item #3800 out of 29961
# Extracting model name for item #3900 out of 29961
# Extracting model name for item #4000 out of 29961
# Extracting model name for item #4100 out of 29961
# Extracting model name for item #4200 out of 29961
# Extracting model name for item #4300 out of 29961
# Extracting model name for item #4400 out of 29961
# Extracting model name for item #4500 out of 29961
# Extracting model name for item #4600 out of 29961
# Extracting model name for item #4700 out of 29961
# Extracting model name for item #4800 out of 29961
# Extracting model name for item #4900 out of 29961
# Extracting model name for item #5000 out of 29961
# Extracting model name for item #5100 out of 29961
# Extracting model name for item #5200 out of 29961
# Extracting model name for item #5300 out of 29961
# Extracting model name for item #5400 out of 29961
# Extracting model name for item #5500 out of 29961
# Extracting model name for item #5600 out of 29961
# Extracting model name for item #5700 out of 29961
# Extracting model name for item #5800 out of 29961
# Extracting model name for item #5900 out of 29961
# Extracting model name for item #6000 out of 29961
# Extracting model name for item #6100 out of 29961
# Extracting model name for item #6200 out of 29961
# Extracting model name for item #6300 out of 29961
# Extracting model name for item #6400 out of 29961
# Extracting model name for item #6500 out of 29961
# Extracting model name for item #6600 out of 29961
# Extracting model name for item #6700 out of 29961
# Extracting model name for item #6800 out of 29961
# Extracting model name for item #6900 out of 29961
# Extracting model name for item #7000 out of 29961
# Extracting model name for item #7100 out of 29961
# Extracting model name for item #7200 out of 29961
# Extracting model name for item #7300 out of 29961
# Extracting model name for item #7400 out of 29961
# Extracting model name for item #7500 out of 29961
# Extracting model name for item #7600 out of 29961
# Extracting model name for item #7700 out of 29961
# Extracting model name for item #7800 out of 29961
# Extracting model name for item #7900 out of 29961
# Extracting model name for item #8000 out of 29961
# Extracting model name for item #8100 out of 29961
# Extracting model name for item #8200 out of 29961
# Extracting model name for item #8300 out of 29961
# Extracting model name for item #8400 out of 29961
# Extracting model name for item #8500 out of 29961
# Extracting model name for item #8600 out of 29961
# Extracting model name for item #8700 out of 29961
# Extracting model name for item #8800 out of 29961
# Extracting model name for item #8900 out of 29961
# Extracting model name for item #9000 out of 29961
# Extracting model name for item #9100 out of 29961
# Extracting model name for item #9200 out of 29961
# Extracting model name for item #9300 out of 29961
# Extracting model name for item #9400 out of 29961
# Extracting model name for item #9500 out of 29961
# Extracting model name for item #9600 out of 29961
# Extracting model name for item #9700 out of 29961
# Extracting model name for item #9800 out of 29961
# Extracting model name for item #9900 out of 29961
# Extracting model name for item #10000 out of 29961
# Extracting model name for item #10100 out of 29961
# Extracting model name for item #10200 out of 29961
# Extracting model name for item #10300 out of 29961
# Extracting model name for item #10400 out of 29961
# Extracting model name for item #10500 out of 29961
# Extracting model name for item #10600 out of 29961
# Extracting model name for item #10700 out of 29961
# Extracting model name for item #10800 out of 29961
# Extracting model name for item #10900 out of 29961
# Extracting model name for item #11000 out of 29961
# Extracting model name for item #11100 out of 29961
# Extracting model name for item #11200 out of 29961
# Extracting model name for item #11300 out of 29961
# Extracting model name for item #11400 out of 29961
# Extracting model name for item #11500 out of 29961
# Extracting model name for item #11600 out of 29961
# Extracting model name for item #11700 out of 29961
# Extracting model name for item #11800 out of 29961
# Extracting model name for item #11900 out of 29961
# Extracting model name for item #12000 out of 29961
# Extracting model name for item #12100 out of 29961
# Extracting model name for item #12200 out of 29961
# Extracting model name for item #12300 out of 29961
# Extracting model name for item #12400 out of 29961
# Extracting model name for item #12500 out of 29961
# Extracting model name for item #12600 out of 29961
# Extracting model name for item #12700 out of 29961
# Extracting model name for item #12800 out of 29961
# Extracting model name for item #12900 out of 29961
# Extracting model name for item #13000 out of 29961
# Extracting model name for item #13100 out of 29961
# Extracting model name for item #13200 out of 29961
# Extracting model name for item #13300 out of 29961
# Extracting model name for item #13400 out of 29961
# Extracting model name for item #13500 out of 29961
# Extracting model name for item #13600 out of 29961
# Extracting model name for item #13700 out of 29961
# Extracting model name for item #13800 out of 29961
# Extracting model name for item #13900 out of 29961
# Extracting model name for item #14000 out of 29961
# Extracting model name for item #14100 out of 29961
# Extracting model name for item #14200 out of 29961
# Extracting model name for item #14300 out of 29961
# Extracting model name for item #14400 out of 29961
# Extracting model name for item #14500 out of 29961
# Extracting model name for item #14600 out of 29961
# Extracting model name for item #14700 out of 29961
# Extracting model name for item #14800 out of 29961
# Extracting model name for item #14900 out of 29961
# Extracting model name for item #15000 out of 29961
# Extracting model name for item #15100 out of 29961
# Extracting model name for item #15200 out of 29961
# Extracting model name for item #15300 out of 29961
# Extracting model name for item #15400 out of 29961
# Extracting model name for item #15500 out of 29961
# Extracting model name for item #15600 out of 29961
# Extracting model name for item #15700 out of 29961
# Extracting model name for item #15800 out of 29961
# Extracting model name for item #15900 out of 29961
# Extracting model name for item #16000 out of 29961
# Extracting model name for item #16100 out of 29961
# Extracting model name for item #16200 out of 29961
# Extracting model name for item #16300 out of 29961
# Extracting model name for item #16400 out of 29961
# Extracting model name for item #16500 out of 29961
# Extracting model name for item #16600 out of 29961
# Extracting model name for item #16700 out of 29961
# Extracting model name for item #16800 out of 29961
# Extracting model name for item #16900 out of 29961
# Extracting model name for item #17000 out of 29961
# Extracting model name for item #17100 out of 29961
# Extracting model name for item #17200 out of 29961
# Extracting model name for item #17300 out of 29961
# Extracting model name for item #17400 out of 29961
# Extracting model name for item #17500 out of 29961
# Extracting model name for item #17600 out of 29961
# Extracting model name for item #17700 out of 29961
# Extracting model name for item #17800 out of 29961
# Extracting model name for item #17900 out of 29961
# Extracting model name for item #18000 out of 29961
# Extracting model name for item #18100 out of 29961
# Extracting model name for item #18200 out of 29961
# Extracting model name for item #18300 out of 29961
# Extracting model name for item #18400 out of 29961
# Extracting model name for item #18500 out of 29961
# Extracting model name for item #18600 out of 29961
# Extracting model name for item #18700 out of 29961
# Extracting model name for item #18800 out of 29961
# Extracting model name for item #18900 out of 29961
# Extracting model name for item #19000 out of 29961
# Extracting model name for item #19100 out of 29961
# Extracting model name for item #19200 out of 29961
# Extracting model name for item #19300 out of 29961
# Extracting model name for item #19400 out of 29961
# Extracting model name for item #19500 out of 29961
# Extracting model name for item #19600 out of 29961
# Extracting model name for item #19700 out of 29961
# Extracting model name for item #19800 out of 29961
# Extracting model name for item #19900 out of 29961
# Extracting model name for item #20000 out of 29961
# Extracting model name for item #20100 out of 29961
# Extracting model name for item #20200 out of 29961
# Extracting model name for item #20300 out of 29961
# Extracting model name for item #20400 out of 29961
# Extracting model name for item #20500 out of 29961
# Extracting model name for item #20600 out of 29961
# Extracting model name for item #20700 out of 29961
# Extracting model name for item #20800 out of 29961
# Extracting model name for item #20900 out of 29961
# Extracting model name for item #21000 out of 29961
# Extracting model name for item #21100 out of 29961
# Extracting model name for item #21200 out of 29961
# Extracting model name for item #21300 out of 29961
# Extracting model name for item #21400 out of 29961
# Extracting model name for item #21500 out of 29961
# Extracting model name for item #21600 out of 29961
# Extracting model name for item #21700 out of 29961
# Extracting model name for item #21800 out of 29961
# Extracting model name for item #21900 out of 29961
# Extracting model name for item #22000 out of 29961
# Extracting model name for item #22100 out of 29961
# Extracting model name for item #22200 out of 29961
# Extracting model name for item #22300 out of 29961
# Extracting model name for item #22400 out of 29961
# Extracting model name for item #22500 out of 29961
# Extracting model name for item #22600 out of 29961
# Extracting model name for item #22700 out of 29961
# Extracting model name for item #22800 out of 29961
# Extracting model name for item #22900 out of 29961
# Extracting model name for item #23000 out of 29961
# Extracting model name for item #23100 out of 29961
# Extracting model name for item #23200 out of 29961
# Extracting model name for item #23300 out of 29961
# Extracting model name for item #23400 out of 29961
# Extracting model name for item #23500 out of 29961
# Extracting model name for item #23600 out of 29961
# Extracting model name for item #23700 out of 29961
# Extracting model name for item #23800 out of 29961
# Extracting model name for item #23900 out of 29961
# Extracting model name for item #24000 out of 29961
# Extracting model name for item #24100 out of 29961
# Extracting model name for item #24200 out of 29961
# Extracting model name for item #24300 out of 29961
# Extracting model name for item #24400 out of 29961
# Extracting model name for item #24500 out of 29961
# Extracting model name for item #24600 out of 29961
# Extracting model name for item #24700 out of 29961
# Extracting model name for item #24800 out of 29961
# Extracting model name for item #24900 out of 29961
# Extracting model name for item #25000 out of 29961
# Extracting model name for item #25100 out of 29961
# Extracting model name for item #25200 out of 29961
# Extracting model name for item #25300 out of 29961
# Extracting model name for item #25400 out of 29961
# Extracting model name for item #25500 out of 29961
# Extracting model name for item #25600 out of 29961
# Extracting model name for item #25700 out of 29961
# Extracting model name for item #25800 out of 29961
# Extracting model name for item #25900 out of 29961
# Extracting model name for item #26000 out of 29961
# Extracting model name for item #26100 out of 29961
# Extracting model name for item #26200 out of 29961
# Extracting model name for item #26300 out of 29961
# Extracting model name for item #26400 out of 29961
# Extracting model name for item #26500 out of 29961
# Extracting model name for item #26600 out of 29961
# Extracting model name for item #26700 out of 29961
# Extracting model name for item #26800 out of 29961
# Extracting model name for item #26900 out of 29961
# Extracting model name for item #27000 out of 29961
# Extracting model name for item #27100 out of 29961
# Extracting model name for item #27200 out of 29961
# Extracting model name for item #27300 out of 29961
# Extracting model name for item #27400 out of 29961
# Extracting model name for item #27500 out of 29961
# Extracting model name for item #27600 out of 29961
# Extracting model name for item #27700 out of 29961
# Extracting model name for item #27800 out of 29961
# Extracting model name for item #27900 out of 29961
# Extracting model name for item #28000 out of 29961
# Extracting model name for item #28100 out of 29961
# Extracting model name for item #28200 out of 29961
# Extracting model name for item #28300 out of 29961
# Extracting model name for item #28400 out of 29961
# Extracting model name for item #28500 out of 29961
# Extracting model name for item #28600 out of 29961
# Extracting model name for item #28700 out of 29961
# Extracting model name for item #28800 out of 29961
# Extracting model name for item #28900 out of 29961
# Extracting model name for item #29000 out of 29961
# Extracting model name for item #29100 out of 29961
# Extracting model name for item #29200 out of 29961
# Extracting model name for item #29300 out of 29961
# Extracting model name for item #29400 out of 29961
# Extracting model name for item #29500 out of 29961
# Extracting model name for item #29600 out of 29961
# Extracting model name for item #29700 out of 29961
# Extracting model name for item #29800 out of 29961
# Extracting model name for item #29900 out of 29961

# %% [markdown]
# **Results of NLP Model Extraction**

# %%
titles_df.ix[0:10,['title','filtered_titles','model_name']]
# Out:
#                                                                          title  \
# 0    canon eos rebel sl1 eos 100d 18.0 mp digital slr camera - black kit w stm
# 1      sony cyber-shot dsc-rx100 20.2mp digital camera - black brand new cheap
# 2   new nib canon eos rebel t6 digital slr camera premium kit 18-55mm 75-300mm
# 3         new canon eos rebel t6 dslr bundle 18-55mm 75-300mm lens bag sd card
# 4              sony nex 6 e pz 16-50mm f3.5-5.6 oss power zoom lens kit camera
# 5                   brand new lumix fz300 4k 24x f2.8 long zoom digital camera
# 6                              nikon d2h camera package shutter clicks 30 474
# 7     panasonic lumix dmc-g7 mirrorless micro four thirds digital camera body
# 8                              sony cyber-shot rx100 ii digital camera - black
# 9                                          nikon d3300 18-55 vr ii kit new box
# 10      sony cyber-shot dsc-hx300 20.4mp digital camera - black. original box.
#
#                            filtered_titles            model_name
# 0        eo rebel l1 eo 100d    lr    w tm        sl1 / eos 100d
# 1           cyber-hot dc-rx100       cheap  cyber-shot dsc-rx100
# 2         nib  eo rebel t6  lr  premium                 rebel t6
# 3         eo rebel t6 dlr bundle   len  d               rebel t6
# 4                nex e pz  f3..6 o   len                  nex-f3
# 5                   fz300 4k 24x f long             hc-wx970k 4k
# 6                 d2h  packa hutter click                    d2h
# 7     dmc-g7 mirrorle micro four third                    dmc-g7
# 8                    cyber-hot rx100 ii             dsc-rx100 ii
# 9                          d3300  vr ii                    d3300
# 10              cyber-hot dc-hx300    .  .             dsc-hx300

# %% [markdown]
# ## Find Lens Information

# %% [markdown]
# ** Use Regex to extract lens information **

# %%
def find_lens(title):
    lenses = []
    
    lens = re.findall(r"\d+\-\d+m{2}", title)
    if lens:
        lenses.extend(lens)
        return lenses
    
    lens = re.findall(r"\d+m{2}", title)
    if lens:
        lenses.extend(lens)
        return lenses

    lens = re.findall(r"\d+\-\d+", title)
    if lens:
        lens = [l + 'mm' for l in lens]
        lenses.extend(lens)
        return lenses

# %% [markdown]
# **Extract**

# %%
titles_df['lens'] = titles_df['title'].apply(find_lens)

# %% [markdown]
# ## Final Result

# %%
titles_df.ix[:50,['title','brand','model_name','similarity_score','lens']]
# Out:
#                                                                              title  \
# 0        canon eos rebel sl1 eos 100d 18.0 mp digital slr camera - black kit w stm
# 1          sony cyber-shot dsc-rx100 20.2mp digital camera - black brand new cheap
# 2       new nib canon eos rebel t6 digital slr camera premium kit 18-55mm 75-300mm
# 3             new canon eos rebel t6 dslr bundle 18-55mm 75-300mm lens bag sd card
# 4                  sony nex 6 e pz 16-50mm f3.5-5.6 oss power zoom lens kit camera
# 5                       brand new lumix fz300 4k 24x f2.8 long zoom digital camera
# 6                                  nikon d2h camera package shutter clicks 30 474
# 7         panasonic lumix dmc-g7 mirrorless micro four thirds digital camera body
# 8                                  sony cyber-shot rx100 ii digital camera - black
# 9                                              nikon d3300 18-55 vr ii kit new box
# 10          sony cyber-shot dsc-hx300 20.4mp digital camera - black. original box.
# 11      as-is canon ds126491 eos rebel t5 digital slr camera kit w battery charger
# 12        olympus e-3 10.1 mp digital slr camera - black body - 23 597 activations
# 13                                         sony cyber-shot dsc-h300 digital camera
# 14            canon eos 7d 18.0 mp digital slr camera w genuine bg-e7 battery grip
# 15                                    nikon 1 j3 14.2mp digital camera body black
# 16                         sony cyber-shot dsc-tx20 16.2 mp digital camera - green
# 17                   pentax k100d super 6.1 mp w da 18-55mm lens 13k shutter count
# 18                                 nikon coolpix aw120 digital camera bundle - red
# 19                                                   sony dsc-hx300 digital camera
# 20      ricoh theta 360 virtual reality vr digital camera - white - like brand new
# 21         polaroid snap touch instant print digital camera lcd display brand new
# 22       pentax pentax optio wg-3 16.0 mp digital camera - black lots accessories
# 23         canon rebel xti 10.1 mp dslr camera silver 18-55mm lens w extra battery
# 24                                                   nikon d70 camera 18-55mm lens
# 25                          canon powershot sx280 hs 12.1mp digital camera - black
# 26   canon powershot sx610 hs full hd wifi digital camera 20.2 mp 18x optical zoom
# 27               canon eos 30d 8.2mp digital camera canon lens ef 35-80mm f1 4.5-6
# 28                            nikon d3100 dx format 10.2mp digital slr camera body
# 29  samsung wb series wb250f 14.2 mp digital smart camera - white touchscreen wifi
# 30    nikon d3000 10.2mp digital slr camera - black kit w af-s dx vr 18-55mm lens
# 31           canon powershot g10 14.7 mp black point shoot digital camera working
# 32                                                                  canon eos body
# 33                                                olympus e-pl1 w 14-40 ex reserve
# 34                                  panasonic lumix dmc-zs25 16.1mp digital camera
# 35                 nikon coolpix l340 20.2 mp digital mint camera - black warranty
# 36                  canon eos digital rebel 300d 6.3 mp digital slr camera - black
# 37          nikon 1 j1 10.1 mp digital camera - white kit w vr 10-30mm lens 27528
# 38                                 canon powershot sx610 hs - wi-fi enabled white
# 39                                                                   olympus e-pl1
# 40         canon rebel xs dslr digital camera 18-55mm zoom lens ultraviolet filter
# 41                          canon eos 50d 15.1 mp digital slr camera - black body
# 42             nikon d40x digital slr camera - black 50mm lens sd cards batteries
# 43                                                  canon 530 hs digital camera hd
# 44                                                    canon eos 40d digital camera
# 45                   sony sel 1855 digital camera 18-55mm - great condition - used
# 46                           canon powershot sx610 hs 20.2 mp digital camera - red
# 47                                                canon powershot s95 10.0 mp 28mm
# 48                                       pentax k-5 iis 16.3 mp digital slr camera
# 49                                                                 nikon d200 body
# 50                  fujifilm finepix series s200exr 12.0 mp digital camera - black
#
#         brand                                          model_name  \
# 0       canon                                      sl1 / eos 100d
# 1        sony                                cyber-shot dsc-rx100
# 2       canon                                            rebel t6
# 3       canon                                            rebel t6
# 4        sony                                              nex-f3
# 5       lumix                                        hc-wx970k 4k
# 6       nikon                                                 d2h
# 7   panasonic                                              dmc-g7
# 8        sony                                        dsc-rx100 ii
# 9       nikon                                               d3300
# 10       sony                                           dsc-hx300
# 11      canon                                            rebel t5
# 12    olympus                                          5d mark ii
# 13       sony                                            dsc-h300
# 14      canon                                                  7d
# 15      nikon                                                  j3
# 16       sony                                cyber-shot dsc-rx100
# 17     pentax                                         k100d super
# 18      nikon                                               aw120
# 19       sony                                           dsc-hx300
# 20      ricoh                                               theta
# 21   polaroid                                          snap touch
# 22     pentax                                          optio wg-2
# 23      canon                                           rebel xti
# 24      nikon                                                 d70
# 25      canon                                          5d mark ii
# 26      canon                                          5d mark ii
# 27      canon                                                 30d
# 28      nikon                                 7200 dx format dslr
# 29    samsung                                              wb250f
# 30      nikon                                               d3000
# 31      canon                                                 g10
# 32      canon                                          5d mark ii
# 33    olympus                                               e-pl1
# 34  panasonic                                            dmc-g7hk
# 35      nikon                                        coolpix l340
# 36      canon                                digital rebel / 300d
# 37      nikon                                                  j1
# 38      canon  pentax k-s2 dslr camera with 18-135mm lens (white)
# 39    olympus                                               e-pl1
# 40      canon                                            rebel xs
# 41      canon                                                 50d
# 42      nikon                                                d40x
# 43      canon                                          5d mark ii
# 44      canon                                                 40d
# 45       sony                                          5d mark ii
# 46      canon                                          5d mark ii
# 47      canon                                          5d mark ii
# 48     pentax                                          digital ii
# 49      nikon                                                d200
# 50   fujifilm                                          5d mark ii
#
#     similarity_score                 lens
# 0           0.450392                 None
# 1           0.450392                 None
# 2           0.450392  [18-55mm, 75-300mm]
# 3           0.450392  [18-55mm, 75-300mm]
# 4           0.450392            [16-50mm]
# 5           0.450392                 None
# 6           0.450392                 None
# 7           0.450392                 None
# 8           0.450392                 None
# 9           0.450392            [18-55mm]
# 10          0.450392                 None
# 11          0.450392                 None
# 12          0.450392                 None
# 13          0.450392                 None
# 14          0.450392                 None
# 15          0.450392                 None
# 16          0.450392                 None
# 17          0.450392            [18-55mm]
# 18          0.450392                 None
# 19          0.450392                 None
# 20          0.450392                 None
# 21          0.450392                 None
# 22          0.450392                 None
# 23          0.450392            [18-55mm]
# 24          0.450392            [18-55mm]
# 25          0.450392                 None
# 26          0.450392                 None
# 27          0.450392            [35-80mm]
# 28          0.450392                 None
# 29          0.450392                 None
# 30          0.450392            [18-55mm]
# 31          0.450392                 None
# 32          0.450392                 None
# 33          0.450392            [14-40mm]
# 34          0.450392                 None
# 35          0.450392                 None
# 36          0.450392                 None
# 37          0.450392            [10-30mm]
# 38          0.450392                 None
# 39          0.450392                 None
# 40          0.450392            [18-55mm]
# 41          0.450392                 None
# 42          0.450392               m]
# 43          0.450392                 None
# 44          0.450392                 None
# 45          0.450392            [18-55mm]
# 46          0.450392                 None
# 47          0.450392               m]
# 48          0.450392                 None
# 49          0.450392                 None
# 50          0.450392                 None

# %%
models
# Out:
# ['5d mark ii',
#  '70d',
#  'd40',
#  'x100t',
#  'd3100',
#  'a7',
#  'a6300',
#  'd3000',
#  'dmc-gh4',
#  'a6000',
#  '6d',
#  't3 / eos 1100d',
#  'd600',
#  'l840',
#  'd700',
#  'd80',
#  'xti / eos 400d',
#  '40d',
#  'xsi / eos 450d',
#  'd90',
#  'd60',
#  '7d',
#  'd70',
#  't1i / eos 500d',
#  'd7200',
#  'd7100',
#  't2i / eos 550d',
#  'd200',
#  '60d',
#  'd50',
#  'xt / eos 350d',
#  't6i / eos d750',
#  'j1',
#  'd5000',
#  'rebel xs',
#  'd610',
#  't3i / eos 600d',
#  'd7000',
#  'd3200',
#  'rebel t3',
#  'l340',
#  'rx100 v',
#  'd3300',
#  'l830',
#  '7d mark ii',
#  'x-t1',
#  'd300',
#  'sx410 is',
#  'xs / eos 1000d',
#  '80d',
#  'd5500',
#  'x-t10',
#  's100',
#  'd40x',
#  'sx50 hs',
#  's110',
#  '30d',
#  'p510',
#  'dmc-lx5',
#  'g11',
#  'sx40 hs',
#  '5d',
#  'dsc-h300',
#  'sx610 hs',
#  '50d',
#  'sx530 hs',
#  'rebel xs / 1000d',
#  'd3',
#  'd70s',
#  '20d',
#  'dsc-rx100',
#  'b500',
#  'p530',
#  'xs / 1000d',
#  'rebel xsi / 450d',
#  'dsc-rx10 ii',
#  'p520',
#  't5i / eos 700d',
#  'a350',
#  'wb350f',
#  'a7r',
#  'd5100',
#  'hero 3+ silver edition',
#  'sx510 hs',
#  'd5300',
#  'a100',
#  'l820',
#  'a77 ii',
#  't6s / eos 760d',
#  'slt-a77',
#  'e-500',
#  'g12',
#  'dslr-a200',
#  'nex-5n',
#  'a3000',
#  'e-510',
#  'a7 ii',
#  'x100s',
#  'a300',
#  't5 / eos 1200d',
#  'rebel xsi',
#  'x10',
#  's7000',
#  'nx1000',
#  'wb1100f',
#  'sl1 / eos 100d',
#  'eos rebel t3',
#  'digital rebel xti / 400d',
#  'dsc-hx300',
#  'e-pl1',
#  'dsc-hx50v',
#  'rebel t6',
#  'm',
#  'g7',
#  'g10',
#  'd800',
#  'd800e',
#  'j3',
#  't4i / eos 650d',
#  'sx30 is',
#  'nex-3n',
#  'g85',
#  'eos rebel t6i',
#  'dmc-fz70 / dmc-fz72',
#  'rebel t1i',
#  '5d mark iii',
#  'e-pm2',
#  's',
#  'sx500 is',
#  'a5000',
#  'dsc-rx100m4',
#  'wb250f',
#  'snap touch',
#  'sx260 hs',
#  'sx280 hs',
#  't5',
#  't3 / 1100d',
#  'sx700 hs',
#  'd750',
#  '1d mark ii',
#  'eos rebel xs',
#  'nex-5r',
#  'dmc-fz1000',
#  'rebel t5',
#  'nex-3',
#  '1ds mark iii',
#  'd5200',
#  'd100',
#  '10d',
#  'sx520 hs',
#  'pen-f',
#  'sx160 is',
#  'a230',
#  'd5600',
#  'dsc-f828',
#  'dsc-hx200v',
#  's9700',
#  'e-m1',
#  'x-e2',
#  'dsc-hx100v',
#  's1',
#  'g9',
#  'l330',
#  'rebel t2i / 550d',
#  'k10d',
#  'd2h',
#  'd300s',
#  'dsc-wx350',
#  'dmc-gh1',
#  'tg-860',
#  '300 hs / ixus 220 hs',
#  'nex-5t',
#  'dmc-gx8',
#  'rebel t6i',
#  'k-x',
#  'nex-5',
#  't6s / eos d760',
#  'g3 x',
#  '350 hs / ixus 275 hs',
#  'ek-gc110',
#  'g15',
#  'snap',
#  'nex-5k',
#  's9500',
#  'p7000',
#  'sl1000',
#  'dmc-zs20/dmc-tz30',
#  'tg-2 ihs',
#  'xp90',
#  'nex-3k',
#  'aw110',
#  'k20d',
#  'nx500',
#  'e-m5 mark ii',
#  'dsc-qx10',
#  'k-3',
#  'x-m1',
#  'dmc-g7hk',
#  's6900',
#  '1 v1',
#  'd1x',
#  'dmc-gh3',
#  'k2000',
#  'x-pro1',
#  'a390',
#  'e-m10',
#  'd30',
#  'dmc-gh2',
#  'slt-a33',
#  'dmc-g1',
#  'm5',
#  'sx600 hs',
#  'dmc-zs40',
#  'd2x',
#  'e-3',
#  's95',
#  'd-lux',
#  'eos 70d',
#  'dsc-w830',
#  'p500',
#  'g7 x',
#  'dsc-tx30',
#  'nx1',
#  'sx710 hs',
#  '1',
#  'aw130',
#  'nex-c3',
#  'g1 x',
#  'l810',
#  's5 pro',
#  't2i',
#  'e-p3',
#  'dsc-h400',
#  't5i',
#  'x-e1',
#  'rebel xt',
#  'dsc-r1',
#  'mini nxf1',
#  's9900',
#  'exilim ex-zr20',
#  't3',
#  's8100',
#  'e-420',
#  'dmc-zs19',
#  'nx300',
#  'e-520',
#  'dmc-lx7',
#  'dsc-qx100',
#  'eos 5d mark ii',
#  'dmc-g3k',
#  'sx20 is',
#  'nex-7k',
#  'digital rebel / eos 300d',
#  'gx1',
#  'aw120',
#  'd500',
#  'nx1100',
#  's3 pro',
#  'nex-f3',
#  's2940',
#  't6',
#  '1d mark iii',
#  'sx150 is',
#  's200exr',
#  'dsc-hx7v',
#  'nex5',
#  'p90',
#  'd3400',
#  'dsc-rx100 iv',
#  'x2',
#  'nex-6',
#  'eos rebel xt',
#  'n',
#  'a5100',
#  's9300',
#  'c9wp',
#  'sx400 is',
#  'd20',
#  'wb800f',
#  'e-p1',
#  'nx2000',
#  'd810',
#  'alpha a6000',
#  'sx60 hs',
#  '340 hs / ixus 265 hs',
#  'nex-7',
#  'a700',
#  'dmc-fz150',
#  'm15',
#  'p600',
#  'dsc-hx20v',
#  'dmc-zs35',
#  'dmc-fz200',
#  'rebel xti',
#  'rebel t2i',
#  's9900w',
#  'a330',
#  'ds6041',
#  'dmc-g3',
#  'p7700',
#  'k-7',
#  'eos rebel xti',
#  'k200',
#  'dmc-zs25k',
#  'z340',
#  'wg-3',
#  'digital ii',
#  's8200',
#  'dmclx100',
#  'sx170 is',
#  '360',
#  'k-r',
#  'dmc-gf3k',
#  'eos rebel t5',
#  't6i',
#  'd1h',
#  'dmc-gx1',
#  'xti',
#  'dslr-a300',
#  'rebel t5i',
#  'dsc-wx220',
#  'j4',
#  'd10',
#  'dslr-a330',
#  '3',
#  'nikon 1 j3',
#  '1d',
#  'a2500',
#  'eos m5',
#  'powershot sx530hs',
#  'x-a1',
#  'm3',
#  'wb35f',
#  'eos rebel',
#  'k-01',
#  '2',
#  'powershot elph 190 is',
#  'xp60',
#  'dsc-wx1',
#  'eos 30d',
#  'eos rebel xsi',
#  'e-10',
#  'e-p2',
#  'xf1',
#  'eos rebel t5i',
#  'q',
#  'v1',
#  'dsc - h7',
#  'x-5',
#  'dsc-hx30v',
#  'slt-a37',
#  'dmc-fz70',
#  'xt',
#  'dmc-sz3',
#  'harinezumi guru',
#  'ex-z90',
#  'nex-f3k',
#  'typ 109',
#  'dsc-tx20',
#  'd3s',
#  'v-lux v1',
#  'k200d',
#  's33',
#  'powershot sx530 hs',
#  'gc120 verizon',
#  '170 is / ixus 170',
#  'theta',
#  'mx-1',
#  'dmc-zs50s',
#  'ek-gc100',
#  'a7s',
#  '160 / ixus 160',
#  'a5000 ilce-5000',
#  'dsc-w7',
#  'coolpix b500',
#  'ds126151',
#  'e-pl2',
#  'a630',
#  'xq1',
#  'k-50',
#  'eos70d18-135',
#  'k-30',
#  'dsc-rx1',
#  'eos rebel t3i',
#  'galaxy camera ek-gc100',
#  'dsc-tx10',
#  'vg-180',
#  'dsc-rx100 ii',
#  'dsc-wx150',
#  'xz-1',
#  'eos 80d',
#  'e-1',
#  '330 hs / ixus 255 hs',
#  'slt-a35',
#  'dmc-ts3/dmc-ft3',
#  'dmc-gh4eb',
#  'canon eos 80d',
#  'az365',
#  'dmc-gf2w',
#  'eos 50d',
#  'coolpix s9700',
#  'k100d super',
#  'powershot',
#  'q7',
#  'ds126191',
#  'coolpix l340',
#  '1ds mark ii',
#  'g7x mark ii',
#  'eos rebel t1i',
#  'rebel t3 / 1100d',
#  'eos 7d',
#  'ex-tr70',
#  's5 is',
#  's6800',
#  'ds126201',
#  's3 is',
#  'ds',
#  'g7 x mark ii',
#  'dmc-fz60 / dmc-fz62',
#  'l320',
#  'sony alpha a7 mirrorless digital camera',
#  'e-m5',
#  'ex-fh20',
#  'eos rebel t6',
#  'dmc-fz35',
#  'e8800',
#  'dmc-gf1',
#  'canon powershot g7 x',
#  'd2hs',
#  'gr',
#  'e-pl3',
#  'fz150',
#  '110 hs / ixus 125 hs',
#  'd33697',
#  'a68',
#  's8300',
#  'sony a6000',
#  'x-s1',
#  'xe-1',
#  '300d',
#  'dmc-g2',
#  'coolpix p510',
#  'rx100',
#  'tough tg-850',
#  'tg-4',
#  'wb110',
#  's30',
#  'universal',
#  'hs25exr',
#  'e-p5',
#  'digital rebel xt',
#  's9750',
#  'coopix p520',
#  's9400w',
#  'tough tg-3',
#  'powershot elph 110 hs',
#  'eos 40d',
#  'e-410',
#  's9150',
#  'omd em5 ii body',
#  'eos digital rebel',
#  'nikon d5200',
#  'df',
#  'eos t3',
#  'e-pl5',
#  'dsc-wx80',
#  'tg-870',
#  'hero +lcd',
#  'rx100 iv',
#  'e-620',
#  'dmc-zs50 / dmc-tz70',
#  'pro slr/n',
#  'd-50',
#  's9450w',
#  'dmc-ts4/dmc-ft4',
#  's5000',
#  '760d',
#  'sd750 / digital ixus 75',
#  'real 3d w3',
#  'dp1x',
#  'e-300',
#  'dsc-hx90v',
#  'sd1 merrill',
#  'coolpix l830',
#  '530 hs',
#  'type 114',
#  'lumix dmc-gh1',
#  'aw1',
#  'gx85k',
#  'mini',
#  'nikon d600',
#  'aw100',
#  'a900',
#  'xz-2',
#  'gh4',
#  'nex 6',
#  'eos t1i',
#  'ds126071',
#  'snaptouch',
#  'hs30exr / hs33exr',
#  'm2',
#  '1d mark iv',
#  'mp-eg1a',
#  'fujifilm x-t10',
#  'sx230 hs',
#  'd3400 dslr camera',
#  'f5',
#  'dmc-g7',
#  'mo-1',
#  'dslr-a700',
#  'sx530hs',
#  'dmc-gm5',
#  's4000',
#  'dmc-gx1x',
#  'mbp854 connect',
#  'coolpix s7000',
#  'g16',
#  'xp95',
#  'wb2200f',
#  'x-e (typ 102)',
#  'l105',
#  'dmc-gf2c',
#  'gear 360',
#  'eos digital rebel xt',
#  'dsc-hx1',
#  'sx620 hs',
#  'ek-gc120',
#  'slt-a57',
#  'powershot g10',
#  'd2xs',
#  's3700',
#  'fuji xt10',
#  'l110',
#  'fuji x e2',
#  's9950w / s9900w series',
#  'illum',
#  'eos 77d 18-55 stm kit',
#  'eos m3',
#  '520 hs / ixus 500 hs',
#  '2 ek-gc200',
#  'wb50f',
#  'eos 5d',
#  'elph 300 hs / ixus 220 hs',
#  'dsc-rx10',
#  'dsc-hx9v',
#  'dmc-g5',
#  'dslr-a390',
#  'rx100 iii',
#  'polaroid',
#  'rebel t3i',
#  's8600',
#  'dsc-hx10',
#  't6 18-55mm',
#  'dsc-w800',
#  'rebel ds6041',
#  'a850',
#  'a77',
#  'a550',
#  '1d mark ii n',
#  'rebel ti1 / 500d',
#  'd7100 kit 18-140',
#  'mini live cv',
#  'nex 5',
#  'e-30',
#  's5200',
#  'dmcgh4',
#  'dsc-hx400v',
#  'canon eos 70d',
#  'dmc-lz40',
#  'xp200',
#  'slt-a58',
#  'hero 4 sessions',
#  'q7 - o2 standard zoom',
#  '5a',
#  'dmc-zs45',
#  'elph 330 hs / ixus 255 hs',
#  'ppbcm16',
#  'canon 40d',
#  'k1000',
#  'tl220',
#  'c-750 ultra zoom',
#  'sp-600uz',
#  'sh-1',
#  'wb850f',
#  'xt 10',
#  'nx3000',
#  'xt eos 350d',
#  'alpha 5100',
#  '1093c001',
#  'sp-800uz',
#  'polsp01ww',
#  'fz100',
#  'dmc-tz5',
#  'sz-15',
#  'digital rebel / 300d',
#  'gr limited edition',
#  'sh-50 ihs',
#  'one / 4mp',
#  'wp10',
#  'sony alpha a77 ii',
#  'hero4 silver edition',
#  'd series d5300',
#  'pss100',
#  'alpha dslr - a100',
#  'coolpixs9500',
#  'dp3',
#  'canon eos rebel t4i 18mp digital camera,18-55mm,55',
#  'max z990',
#  'k10 anti shake reduction',
#  'assorted',
#  'tlc200 pro',
#  'dmc-tz70',
#  'rebel t6s',
#  'n80',
#  'black',
#  'eos xs',
#  'fdr-x1000v',
#  'polaroid z2300',
#  'ex2f',
#  'z5010',
#  '5d mark iv',
#  'dsc-hx400',
#  'socialmatic smtp01',
#  'slt-a77v',
#  'nex 3n',
#  'z612',
#  'elph 190 is',
#  'wg-30',
#  'dmc-lz30',
#  'ilce-6500',
#  'slt-a65',
#  'galaxy ek-gc200',
#  'g5 x',
#  'nikon d7200',
#  'moto mods hasselblad',
#  'dsc-rx10m3',
#  'sp-100ee',
#  'dsc-p200',
#  'p712',
#  '110',
#  'lumix dmc-gf5',
#  'gxr',
#  'dsc-h50',
#  'canon powershot elph 170 is',
#  'eos 7d mark ii',
#  'dmc-zs10/dmc-tz20',
#  'dmc-zs30 / dmc-tz40',
#  's9800',
#  'k-70',
#  'dmc-lx3',
#  'e-ep3',
#  'd-lux (type 109) soldi gray',
#  'p7100',
#  'k 20 d',
#  'dmc-fz8',
#  'p7800',
#  'fuji x70',
#  'dmc-fz5',
#  'c',
#  'ilce-5000',
#  'dmc-gf1c',
#  'kodak fz53-bk',
#  'nikon d3100',
#  '1300d / t6',
#  'sony cyber-shot dsc-rx10 ii',
#  's210',
#  'sigma dp2',
#  's2 pro',
#  's120',
#  'dsc-hx60v',
#  's9600',
#  'gh 1',
#  'dscw810',
#  'dmc-gf7',
#  'slt-a55',
#  's70',
#  'canon rebel t5 / eos 1200d / kiss x70',
#  'eos 350d',
#  'dscrx100m3/b',
#  't7i / eos 800d',
#  'digital elph sd1200 is / digital ixus 95 is',
#  'p80',
#  'c195',
#  'pixpro az361',
#  'dmc-zs3/dmc-tz7',
#  'lunar h',
#  'x400',
#  'finepix xp 80',
#  'az361',
#  'dsc-tx200v',
#  'finepix xp60',
#  'vr-340 / d-750',
#  'm5350',
#  'dmc-g7k',
#  'tg-1 ihs',
#  'epl5',
#  'ilce-7r',
#  'leica x2  black',
#  'dsc-t77',
#  'pen mini e-pm1',
#  'g6',
#  'dmc-l1',
#  'sd980 is / digital ixus 200 is',
#  'p330',
#  'digital elph sd4500 is / ixus 1000 hs',
#  's9950w',
#  'canon eos rebel t5i / 700d',
#  '5700',
#  'dsc-hx5v',
#  'ilce-7',
#  'l310',
#  'dmc-gf2',
#  'dsch300/b',
#  'n6006',
#  'pentax k-s2 dslr camera with 18-135mm lens (white)',
#  'k-3 ii',
#  'm10',
#  'ds126411',
#  'eos 7d mark i',
#  'eos rebel t2i',
#  'nex-3nl/wq',
#  'a33',
#  'd7200 1555',
#  'contarex',
#  'wg-2',
#  'xe-2',
#  'nx300 body only',
#  'eos xsi',
#  'dmc-g5k',
#  'eos rebel 400d',
#  'yuntyhscus',
#  'dsc-rx10 iii',
#  'c-5060 wide zoom',
#  'ex-fh25',
#  'eos 1d',
#  'ex-zr1200',
#  'e 620',
#  'm71',
#  'dmc-gh1keg9k',
#  'e-pm1',
#  'chdhn-302',
#  'mv800',
#  'digital elph sd3500 is / ixus 210',
#  'sx710',
#  'xsi',
#  'hc-wx970k 4k',
#  '77d',
#  'nikon d3300',
#  'ex-tr200',
#  's800c',
#  '3d',
#  'e-450',
#  'canon rebel t1i',
#  'lumix lx5 black',
#  'coolpix p7100',
#  'ie 4038w',
#  'dmc-zs19kbp',
#  '6 g-star raw',
#  'a3100 is',
#  '\xce\xbc-9000',
#  'd7100 13302',
#  'coolpixp7100',
#  's9900w series',
#  'sx110 is',
#  's6200',
#  'z1012 is',
#  '5d mark 2',
#  'nikon 1  v1',
#  'ilce6000h',
#  'g9 x',
#  'chdhn302',
#  'a2600',
#  'coolpix s3700',
#  'p900',
#  'wb150f',
#  'dmc-ts5',
#  'dmc-g7kk',
#  'dmc-gh2h',
#  'tlc200gw',
#  'sd9',
#  'power shot g - 10',
#  'z981',
#  'gx 9',
#  'v2',
#  'p5000',
#  'sony cybershot dsc-h5',
#  'w60',
#  'hero 3 black edition',
#  '115 is / ixus 170',
#  'canon powershot g12',
#  'dmc-ts5 / dmc-ft5',
#  't1i',
#  'hdr-cx220',
#  'fujifilm x-e2s xf18-55 kit blk',
#  'sm-c200',
#  'tlc200gw+ath100+sd',
#  's1100pj',
#  'e-pl7',
#  'f30',
#  '800',
#  'canon t2i',
#  '5n',
#  'z812 is',
#  'e520',
#  'dslr-a100',
#  'survey 2 visible rgb',
#  'g1xmarkii',
#  'canon g7x mark ii',
#  'dmc-g85',
#  'a620',
#  'd 7000',
#  'dmc-gf3c',
#  '18471',
#  '114',
#  'fz300k',
#  'fz2500',
#  'dsc-f717',
#  'ephothe 1280',
#  's2800',
#  '650d',
#  'sd quattro',
#  'eos 300d',
#  'dsc-s730',
#  '1030sw',
#  'cyber-shot dsc-f828',
#  'eos sl1',
#  'dmc-gf5x',
#  'mobilight 300',
#  'ds126291',
#  'e1410sw-bk',
#  '5d classic',
#  'ds126051',
#  'dsc-h20',
#  'sony a6300',
#  'xp80',
#  'ex-h20g',
#  's7c',
#  'dsc-rx100 v',
#  'dsc-h200',
#  'canon 70d with 18-55mm',
#  'powershot g7 x mark ii',
#  'dsc-w290',
#  's6000fd',
#  'ic-700',
#  'dmc-zs100',
#  'sm-c200nzwaxar',
#  'dmc-gm5kk',
#  'wg-4',
#  'bcc100',
#  'd-lux typ 109',
#  'dmc-zs20',
#  'finepix s8630',
#  'yac-436',
#  's4400',
#  'powershot sx520 hs',
#  'elph 320 hs / ixus 240 hs',
#  'fuji x100t',
#  'dsc-h55',
#  'aw 110',
#  'dsc-tx55',
#  'dmc-ts30-r',
#  'ex-h10',
#  'tg-630 ihs',
#  'd-lux type 109',
#  'rebel 450d',
#  'x1',
#  'rx100m4',
#  'alpha',
#  'elb2v9wpo',
#  'optio wg-2',
#  'zr400',
#  'c-2100 ultra zoom',
#  'keymission 80',
#  'virb ultra 30',
#  '360 hs',
#  'hero 3+',
#  '6300',
#  'dl',
#  'd 80',
#  'sony rx10 m2',
#  'k7',
#  'alpha a200',
#  'a650 is',
#  'v360',
#  'dmc-g5kbody',
#  'd-lux 3',
#  'sp-550 uz',
#  'om-d e-m10',
#  'dmc-gx7',
#  'zs30, tz40',
#  'az522',
#  'k-500',
#  '18191 v-lux 4',
#  'e3',
#  'hs50exr',
#  '7200 dx format dslr',
#  's6500',
#  'ex-tr150',
#  'ex-zr1000',
#  'tg-870 tough',
#  'leica t',
#  'dmc-gf3',
#  'd-lux4',
#  'a290',
#  '8700',
#  'alpha 6300',
#  'sx420 is',
#  'dmc-gh3a',
#  '6',
#  'wg-3 gps',
#  'sx530',
#  's4200',
#  '9694b031',
#  '1575',
#  'gr digital',
#  'ec-wb380fbpeus',
#  'type 109',
#  'dmcgf2',
#  'xp',
#  'd5600 dslr camera',
#  '3500',
#  'eos rebel xsi 450d',
#  'zs100',
#  'om-d e-m5 ii',
#  'pro815',
#  'rebel',
#  'sz-12',
#  'x-t20',
#  'sl1/100d',
#  'k3 prestige edition',
#  '100 hs / ixus 115 hs',
#  'hero4',
#  'digital elph s110 / digital ixus v',
#  'sl1',
#  'd 7200',
#  '1d iii',
#  'k-5 iis',
#  'lytro light field',
#  'brc-300',
#  'dsc-rbb2',
#  'dmc-fz47',
#  'r-d1',
#  'lumix fz 200',
#  's4250',
#  'sx410',
#  'canon eos 60d',
#  'eos digital rebel xti',
#  'sx130 is',
#  'canon eos digital rebel xti',
#  '*ist d l',
#  'slt-a99',
#  'j5',
#  'rebel xsi dslr',
#  'coolpix l840',
#  'a10',
#  'dmc-fz40/dmc-fz45',
#  'e-5',
#  'dmc-gm1',
#  'p100',
#  'sx 610 hs',
#  'd4300',
#  'd-lux 4',
#  'a3500 is',
#  'aw 100',
#  'a2300',
#  'a3400 is',
#  '750',
#  'sigma sd quattro',
#  'dsc-h3',
#  'az501',
#  'x (typ 113)',
#  'coolpix l120',
#  'x-t1 18-55mm kit',
#  'sx530 hs power shot',
#  'dsc wx 350',
#  'rebel t5i / 700d',
#  'pentax k-70',
#  'cyber-shot dsc-rx100',
#  'a7s ii',
#  'd3x',
#  'dmc-zs7/dmc-tz10',
#  'tg-820 ihs',
#  'stylus xz-2',
#  'chdhx-302',
#  'ex-zs5',
#  's2950',
#  'dsc-rx100m5',
#  'om-d e-m1',
#  'eos m10',
#  'h2',
#  'digital rebel',
#  'dsc-t110',
#  'stylus',
#  'coolpix',
#  'elph 310 hs / ixus 230 hs',
#  '0068946673886',
#  'dsc-wx500',
#  'sx40hs',
#  'pro2',
#  'eos-1d mark iv',
#  ...]

# %% [markdown]
# **Test**

# %%
titles_df.ix[:50,['title','filtered_titles']]

# %% [markdown]
# Test Cases:
# <br>18-55
# <br>28mm
# <br>18-55mm
# <br>75-300mm

# %%
test_index = 9
test_title = titles_df['title'].iloc[test_index]
print test_title
lenses = []
# lens = re.findall(r"\d+\-\d+m{2}", test_title)
# lenses.extend(lens)
# print lenses
# print re.findall(r"\d+m{2}", test_title)
lenses = find_lens(test_title)
print lenses
# Out:
# nikon d3300 18-55 vr ii kit new box
# [u'18-55']

# %% [markdown]
# **Development**

# %%
test_title = ' 18-55mm '
# test_title = ',28mm '
# test_title = ' 18-55'

print re.findall(r"\d+\-\d+m{2}", test_title)

print re.findall(r"\d+m{2}", test_title)

print re.findall(r"\d+\-\d+", test_title)






# print re.findall(r"\d+\-\d+mm",test_title)

# print re.findall(r"[^\w-]\d+mm",test_title)

# for match in re.findall(r"[^\w]?\d{2,3}\-\d{2,3}[^\w]?",test_title):
#     print match
# Out:
# ['18-55mm']
# ['55mm']
# ['18-55']
